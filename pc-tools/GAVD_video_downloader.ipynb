# %% [raw]
# # GAVD Video Downloader
#
# This notebook provides a simple two-step process to download YouTube videos from the GAVD dataset using yt-dlp.
#
# ## Overview
# - **Step 1**: Install yt-dlp
# - **Step 2**: Download videos using URLs from the GAVD dataset

# %%
# Install yt-dlp
# %pip install -U yt-dlp --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# ## Step 2: Download Video (Command-line version)

# %%
# Download video using command-line version with higher resolution options
# Choose one of the following format options:

# Option 1: Best quality video + best audio (may result in separate files that get merged)
# !yt-dlp -f "bestvideo+bestaudio" -o "%(title)s.%(ext)s" https://www.youtube.com/watch?v=RB_bNAHj0Kg

# Option 2: Specific resolution (uncomment to use)
# !yt-dlp -f "best[height<=1080]" -o "%(title)s.%(ext)s" https://www.youtube.com/watch?v=RB_bNAHj0Kg

# Option 3: Best available up to 4K (uncomment to use)
# !yt-dlp -f "best[height<=2160]" -o "%(title)s.%(ext)s" https://www.youtube.com/watch?v=RB_bNAHj0Kg

# Option 4: Prefer higher resolution with fallback (uncomment to use)
# !yt-dlp -f "bestvideo[height>=720]+bestaudio/best" -o "%(title)s.%(ext)s" https://www.youtube.com/watch?v=RB_bNAHj0Kg

# %% [raw]
# ## Python Version Example

# %%
import yt_dlp

url = "https://www.youtube.com/watch?v=RB_bNAHj0Kg"

# Option 1: Highest quality (recommended)
ydl_opts = {
    "format": "bestvideo+bestaudio",
    "outtmpl": "%(title)s.%(ext)s",
    "ignoreerrors": True,           # Don't abort on errors
    "no_warnings": False,           # Show warnings but continue
    "keepvideo": True,              # Keep video file even if merge fails
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])

# Alternative options (uncomment to use instead):

# Option 2: Specific resolution up to 1080p
# ydl_opts = {
#     "format": "best[height<=1080]",
#     "outtmpl": "%(title)s.%(ext)s",
# }

# Option 3: Specific resolution up to 4K
# ydl_opts = {
#     "format": "best[height<=2160]",
#     "outtmpl": "%(title)s.%(ext)s",
# }

# Option 4: Prefer 720p+ with fallback
# ydl_opts = {
#     "format": "bestvideo[height>=720]+bestaudio/best",
#     "outtmpl": "%(title)s.%(ext)s",
# }
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RB_bNAHj0Kg
# [youtube] RB_bNAHj0Kg: Downloading webpage
# [youtube] RB_bNAHj0Kg: Downloading tv client config
# [youtube] RB_bNAHj0Kg: Downloading tv player API JSON
# [youtube] RB_bNAHj0Kg: Downloading ios player API JSON
# [youtube] RB_bNAHj0Kg: Downloading m3u8 information
# [info] RB_bNAHj0Kg: Downloading 1 format(s): 137+251
# [download] Destination: “From Skin to Skeleton ：Towards Biomechanically Accurate 3D Digital Humans.f137.mp4
# [download]  23.2% of   42.70MiB at    5.40MiB/s ETA 00:06
# ERROR: unable to download video data: HTTP Error 403: Forbidden

# %% [raw]
# ## Download Videos from GAVD Dataset

# %%
# Load GAVD dataset to get video URLs
import pandas as pd
import os

# Load first dataset part to get URLs
data_dir = '../GAVD/data/'
first_csv = os.path.join(data_dir, 'GAVD_Clinical_Annotations_1.csv')
df = pd.read_csv(first_csv)

# Display available columns
print("Available columns:", list(df.columns))
print(f"Dataset shape: {df.shape}")

# Check if URL column exists and show sample URLs
if 'url' in df.columns:
    unique_urls = df['url'].dropna().unique()
    print(f"\nFound {len(unique_urls)} unique video URLs")
    print("Sample URLs:")
    for i, url in enumerate(unique_urls[:5]):
        print(f"  {i+1}. {url}")
else:
    print("No 'url' column found in the dataset")
# Out:
# Available columns: ['seq', 'frame_num', 'cam_view', 'gait_event', 'dataset', 'gait_pat', 'bbox', 'vid_info', 'id', 'url']
# Dataset shape: (91624, 10)
#
# Found 69 unique video URLs
# Sample URLs:
#   1. https://www.youtube.com/watch?v=B5hrxKe2nP8
#   2. https://www.youtube.com/watch?v=TgkxrrhnvlM
#   3. https://www.youtube.com/watch?v=5SBtTbfELUU
#   4. https://www.youtube.com/watch?v=0gAHlm79Bjo
#   5. https://www.youtube.com/watch?v=jzkn287X-84
# C:\Users\1nkas-Strix-4090-ll\AppData\Local\Temp\ipykernel_32036\169365016.py:8: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(first_csv)

# %%
# Download a single video from GAVD dataset (highest quality)
import yt_dlp

cookies_path = "../tools/youtube_cookies.txt"
# Select first available URL from the dataset
if 'url' in df.columns and len(df['url'].dropna()) > 0:
    sample_url = df['url'].dropna().iloc[0]
    print(f"Downloading video from: {sample_url}")
    
    ydl_opts = {
        "format": "best[ext=mp4]/bestvideo[ext=mp4]+bestaudio[ext=m4a]/best",
        "merge_output_format": "mp4",
        "outtmpl": "GAVD_%(id)s.%(ext)s",  # saves as GAVD_<id>.mp4
        "cookiefile": cookies_path,
        "ignoreerrors": True,
        "continuedl": True,
        "retries": 3,
        "fragment_retries": 10,
        "writeinfojson": False,
        "keepvideo": False,
        "concurrent_fragment_downloads": 1,
    }
    
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([sample_url])
        print("Download completed successfully!")
    except Exception as e:
        print(f"Error downloading video: {e}")
else:
    print("No valid URLs found in the dataset")
# Out:
# Downloading video from: https://www.youtube.com/watch?v=B5hrxKe2nP8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=B5hrxKe2nP8
# [youtube] B5hrxKe2nP8: Downloading webpage
# [youtube] B5hrxKe2nP8: Downloading tv client config
# [youtube] B5hrxKe2nP8: Downloading tv player API JSON
# [info] B5hrxKe2nP8: Downloading 1 format(s): 18
# [download] Destination: GAVD_B5hrxKe2nP8.mp4
# [download] 100% of    5.25MiB in 00:00:02 at 1.96MiB/s
# Download completed successfully!

# %% [raw]
# ## Batch Download (Optional)

# %%
# BATCH DOWNLOAD: Process all GAVD annotation files and download unique videos
import yt_dlp
import os
import pandas as pd
from collections import defaultdict
import time

os.makedirs("GAVD-videos", exist_ok=True)

# Process all 5 annotation files
data_dir = '../GAVD/data/'
annotation_files = [
    'GAVD_Clinical_Annotations_1.csv',
    'GAVD_Clinical_Annotations_2.csv', 
    'GAVD_Clinical_Annotations_3.csv',
    'GAVD_Clinical_Annotations_4.csv',
    'GAVD_Clinical_Annotations_5.csv'
]

print("🔍 Processing all GAVD annotation files...")
all_videos = {}  # Dictionary to store unique videos: {video_id: url}
video_info = defaultdict(dict)  # Store additional info for each video

for i, filename in enumerate(annotation_files, 1):
    filepath = os.path.join(data_dir, filename)
    print(f"📁 Loading {filename}...")
    
    try:
        # Load with low_memory=False to avoid dtype warnings
        df_temp = pd.read_csv(filepath, low_memory=False)
        
        # Extract unique video URLs from this file
        valid_rows = df_temp[df_temp['url'].notna() & df_temp['id'].notna()]
        
        for _, row in valid_rows.iterrows():
            video_id = row['id']
            video_url = row['url']
            
            if video_id not in all_videos:
                all_videos[video_id] = video_url
                # Store additional metadata
                video_info[video_id] = {
                    'gait_pat': row.get('gait_pat', 'unknown'),
                    'dataset': row.get('dataset', 'unknown'),
                    'vid_info': row.get('vid_info', {}),
                    'source_file': filename
                }
        
        unique_in_file = len(valid_rows['id'].unique())
        print(f"   ✓ Found {unique_in_file} unique videos in {filename}")
        
    except Exception as e:
        print(f"   ❌ Error processing {filename}: {e}")

print(f"\n📊 SUMMARY:")
print(f"Total unique videos found: {len(all_videos)}")
print(f"Ready to download {len(all_videos)} videos")

# Show sample of what we found
print(f"\n📋 Sample videos to download:")
sample_videos = list(all_videos.items())[:5]
for video_id, url in sample_videos:
    gait_type = video_info[video_id]['gait_pat']
    print(f"  • {video_id} ({gait_type}): {url}")

if len(all_videos) > 5:
    print(f"  ... and {len(all_videos) - 5} more videos")

# Ask user confirmation before starting batch download
print(f"\n⚠️  This will download {len(all_videos)} videos. This may take a while and use significant bandwidth.")
print("💡 TIP: You can interrupt the process anytime with Ctrl+C")

# Download configuration
ydl_opts = {
    "format": "best[ext=mp4]/bestvideo[ext=mp4]+bestaudio[ext=m4a]/best",
    "merge_output_format": "mp4",
    "outtmpl": "GAVD_%(id)s.%(ext)s",  # saves as GAVD_<id>.mp4
    "cookiefile": cookies_path,
    "ignoreerrors": True,
    "continuedl": True,
    "retries": 3,
    "fragment_retries": 10,
    "writeinfojson": False,
    "keepvideo": False,
    "concurrent_fragment_downloads": 1,
}



# Start batch download
print(f"\n🚀 Starting batch download of {len(all_videos)} videos...")
downloaded_count = 0
failed_count = 0
failed_videos = []

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    for i, (video_id, video_url) in enumerate(all_videos.items(), 1):
        gait_type = video_info[video_id]['gait_pat']
        
        print(f"\n[{i}/{len(all_videos)}] Downloading: {video_id} ({gait_type})")
        print(f"URL: {video_url}")
        
        try:
            ydl.download([video_url])
            downloaded_count += 1
            print(f"✅ Success! ({downloaded_count} completed)")
            
            # Small delay to be respectful to YouTube
            time.sleep(1)
            
        except Exception as e:
            failed_count += 1
            failed_videos.append((video_id, str(e)))
            print(f"❌ Failed: {e}")
            continue

# Final summary
print(f"\n🎉 BATCH DOWNLOAD COMPLETE!")
print(f"✅ Successfully downloaded: {downloaded_count} videos")
print(f"❌ Failed downloads: {failed_count} videos")

if failed_videos:
    print(f"\n📋 Failed videos:")
    for video_id, error in failed_videos[:10]:  # Show first 10 failures
        print(f"  • {video_id}: {error}")
    if len(failed_videos) > 10:
        print(f"  ... and {len(failed_videos) - 10} more failures")

print(f"\n📁 All downloaded videos are saved in: GAVD-videos/")
print("🔍 Each video is saved with its GAVD ID as filename")
print("💡 Note: You may have separate video (.mp4) and audio (.webm) files for highest quality")
# Out:
# 🔍 Processing all GAVD annotation files...
# 📁 Loading GAVD_Clinical_Annotations_1.csv...
#    ✓ Found 69 unique videos in GAVD_Clinical_Annotations_1.csv
# 📁 Loading GAVD_Clinical_Annotations_2.csv...
#    ✓ Found 80 unique videos in GAVD_Clinical_Annotations_2.csv
# 📁 Loading GAVD_Clinical_Annotations_3.csv...
#    ✓ Found 72 unique videos in GAVD_Clinical_Annotations_3.csv
# 📁 Loading GAVD_Clinical_Annotations_4.csv...
#    ✓ Found 69 unique videos in GAVD_Clinical_Annotations_4.csv
# 📁 Loading GAVD_Clinical_Annotations_5.csv...
#    ✓ Found 73 unique videos in GAVD_Clinical_Annotations_5.csv
#
# 📊 SUMMARY:
# Total unique videos found: 348
# Ready to download 348 videos
#
# 📋 Sample videos to download:
#   • B5hrxKe2nP8 (parkinsons): https://www.youtube.com/watch?v=B5hrxKe2nP8
#   • TgkxrrhnvlM (abnormal): https://www.youtube.com/watch?v=TgkxrrhnvlM
#   • 5SBtTbfELUU (abnormal): https://www.youtube.com/watch?v=5SBtTbfELUU
#   • 0gAHlm79Bjo (abnormal): https://www.youtube.com/watch?v=0gAHlm79Bjo
#   • jzkn287X-84 (style): https://www.youtube.com/watch?v=jzkn287X-84
#   ... and 343 more videos
#
# ⚠️  This will download 348 videos. This may take a while and use significant bandwidth.
# 💡 TIP: You can interrupt the process anytime with Ctrl+C
#
# 🚀 Starting batch download of 348 videos...
#
# [1/348] Downloading: B5hrxKe2nP8 (parkinsons)
# URL: https://www.youtube.com/watch?v=B5hrxKe2nP8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=B5hrxKe2nP8
# [youtube] B5hrxKe2nP8: Downloading webpage
# [youtube] B5hrxKe2nP8: Downloading tv client config
# [youtube] B5hrxKe2nP8: Downloading tv player API JSON
# [info] B5hrxKe2nP8: Downloading 1 format(s): 18
# [download] Destination: GAVD_B5hrxKe2nP8.mp4
# [download] 100% of    5.25MiB in 00:00:02 at 1.79MiB/s
# ✅ Success! (1 completed)
#
# [2/348] Downloading: TgkxrrhnvlM (abnormal)
# URL: https://www.youtube.com/watch?v=TgkxrrhnvlM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TgkxrrhnvlM
# [youtube] TgkxrrhnvlM: Downloading webpage
# [youtube] TgkxrrhnvlM: Downloading tv client config
# [youtube] TgkxrrhnvlM: Downloading tv player API JSON
# [info] TgkxrrhnvlM: Downloading 1 format(s): 18
# [download] Destination: GAVD_TgkxrrhnvlM.mp4
# [download] 100% of    4.05MiB in 00:00:03 at 1.26MiB/s
# ✅ Success! (2 completed)
#
# [3/348] Downloading: 5SBtTbfELUU (abnormal)
# URL: https://www.youtube.com/watch?v=5SBtTbfELUU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5SBtTbfELUU
# [youtube] 5SBtTbfELUU: Downloading webpage
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 104
#     101 print(f"URL: {video_url}")
#     103 try:
# --> 104     ydl.download([video_url])
#     105     downloaded_count += 1
#     106     print(f"✅ Success! ({downloaded_count} completed)")
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\YoutubeDL.py:3644, in YoutubeDL.download(self, url_list)
#    3641     raise SameFileError(outtmpl)
#    3643 for url in url_list:
# -> 3644     self.__download_wrapper(self.extract_info)(
#    3645         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3647 return self._download_retcode
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\YoutubeDL.py:3617, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3614 @functools.wraps(func)
#    3615 def wrapper(*args, **kwargs):
#    3616     try:
# -> 3617         res = func(*args, **kwargs)
#    3618     except CookieLoadError:
#    3619         raise
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\YoutubeDL.py:1651, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1649             raise ExistingVideoReached
#    1650         break
# -> 1651     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1652 else:
#    1653     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\YoutubeDL.py:1662, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1660 while True:
#    1661     try:
# -> 1662         return func(self, *args, **kwargs)
#    1663     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1664         raise
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\YoutubeDL.py:1797, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1794 self._apply_header_cookies(url)
#    1796 try:
# -> 1797     ie_result = ie.extract(url)
#    1798 except UserNotLive as e:
#    1799     if process:
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\extractor\common.py:749, in InfoExtractor.extract(self, url)
#     746 self.initialize()
#     747 self.to_screen('Extracting URL: %s' % (
#     748     url if self.get_param('verbose') else truncate_string(url, 100, 20)))
# --> 749 ie_result = self._real_extract(url)
#     750 if ie_result is None:
#     751     return None
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\extractor\youtube\_video.py:3718, in YoutubeIE._real_extract(self, url)
#    3715 base_url = self.http_scheme() + '//www.youtube.com/'
#    3716 webpage_url = base_url + 'watch?v=' + video_id
# -> 3718 webpage, master_ytcfg, player_responses, player_url = self._download_player_responses(url, smuggled_data, video_id, webpage_url)
#    3720 playability_statuses = traverse_obj(
#    3721     player_responses, (..., 'playabilityStatus'), expected_type=dict)
#    3723 trailer_video_id = get_first(
#    3724     playability_statuses,
#    3725     ('errorScreen', 'playerLegacyDesktopYpcTrailerRenderer', 'trailerVideoId'),
#    3726     expected_type=str)
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\extractor\youtube\_video.py:3678, in YoutubeIE._download_player_responses(self, url, smuggled_data, video_id, webpage_url)
#    3676     if pp:
#    3677         query['pp'] = pp
# -> 3678     webpage = self._download_webpage_with_retries(webpage_url, video_id, query=query)
#    3680 master_ytcfg = self.extract_ytcfg(video_id, webpage) or self._get_default_ytcfg()
#    3682 player_responses, player_url = self._extract_player_responses(
#    3683     self._get_requested_clients(url, smuggled_data),
#    3684     video_id, webpage, master_ytcfg, smuggled_data)
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\extractor\youtube\_base.py:789, in YoutubeBaseInfoExtractor._download_webpage_with_retries(self, retry_fatal, retry_on_status, *args, **kwargs)
#     787 for retry in self.RetryManager(fatal=retry_fatal):
#     788     try:
# --> 789         return self._download_webpage(*args, **kwargs)
#     790     except ExtractorError as e:
#     791         if isinstance(e.cause, network_exceptions):
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\extractor\common.py:1195, in InfoExtractor._download_webpage(self, url_or_request, video_id, note, errnote, fatal, tries, timeout, *args, **kwargs)
#    1193 while True:
#    1194     try:
# -> 1195         return self.__download_webpage(url_or_request, video_id, note, errnote, None, fatal, *args, **kwargs)
#    1196     except IncompleteRead as e:
#    1197         try_count += 1
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\extractor\common.py:1146, in InfoExtractor.__create_download_methods.<locals>.download_content(self, url_or_request, video_id, note, errnote, transform_source, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#    1144     kwargs.pop('transform_source')
#    1145 # The method is fetched by name so subclasses can override _download_..._handle
# -> 1146 res = getattr(self, download_handle.__name__)(url_or_request, video_id, **kwargs)
#    1147 return res if res is False else res[0]
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\extractor\common.py:975, in InfoExtractor._download_webpage_handle(self, url_or_request, video_id, note, errnote, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#     973     assert not fatal
#     974     return False
# --> 975 content = self._webpage_read_content(urlh, url_or_request, video_id, note, errnote, fatal,
#     976                                      encoding=encoding, data=data)
#     977 if content is False:
#     978     assert not fatal
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\extractor\common.py:1038, in InfoExtractor._webpage_read_content(self, urlh, url_or_request, video_id, note, errnote, fatal, prefix, encoding, data)
#    1035 def _webpage_read_content(self, urlh, url_or_request, video_id, note=None, errnote=None, fatal=True,
#    1036                           prefix=None, encoding=None, data=None):
#    1037     try:
# -> 1038         webpage_bytes = urlh.read()
#    1039     except TransportError as err:
#    1040         errmsg = f'{video_id}: Error reading response: {err.msg}'
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\yt_dlp\networking\_requests.py:144, in RequestsResponseAdapter.read(self, amt)
#     141 def read(self, amt: int | None = None):
#     142     try:
#     143         # Interact with urllib3 response directly.
# --> 144         return self.fp.read(amt, decode_content=True)
#     146     # See urllib3.response.HTTPResponse.read() for exceptions raised on read
#     147     except urllib3.exceptions.SSLError as e:
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\urllib3\response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     977     if len(self._decoded_buffer) >= amt:
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#     984 if not data and len(self._decoded_buffer) == 0:
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\urllib3\response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)
#     912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#     914         self._fp.close()
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\site-packages\urllib3\response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     884     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\http\client.py:460, in HTTPResponse.read(self, amt)
#     457     return b""
#     459 if self.chunked:
# --> 460     return self._read_chunked(amt)
#     462 if amt is not None:
#     463     if self.length is not None and amt > self.length:
#     464         # clip the read to the "end of response"
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\http\client.py:583, in HTTPResponse._read_chunked(self, amt)
#     581 try:
#     582     while True:
# --> 583         chunk_left = self._get_chunk_left()
#     584         if chunk_left is None:
#     585             break
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\http\client.py:566, in HTTPResponse._get_chunk_left(self)
#     564     self._safe_read(2)  # toss the CRLF at the end of the chunk
#     565 try:
# --> 566     chunk_left = self._read_next_chunk_size()
#     567 except ValueError:
#     568     raise IncompleteRead(b'')
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\http\client.py:526, in HTTPResponse._read_next_chunk_size(self)
#     524 def _read_next_chunk_size(self):
#     525     # Read the next chunk size from the file
# --> 526     line = self.fp.readline(_MAXLINE + 1)
#     527     if len(line) > _MAXLINE:
#     528         raise LineTooLong("chunk size")
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\1nkas-Strix-4090-ll\miniconda3\envs\hsmr\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# SEQUENCE EXTRACTION: Create individual sequence videos from downloaded videos
import os
import pandas as pd
import subprocess
import json
from collections import defaultdict
import glob

# Create sequences folder
sequences_dir = "GAVD-sequences"
os.makedirs(sequences_dir, exist_ok=True)

# Load all annotation files to get sequence information
data_dir = 'GAVD/data/'
annotation_files = [
    'GAVD_Clinical_Annotations_1.csv',
    'GAVD_Clinical_Annotations_2.csv', 
    'GAVD_Clinical_Annotations_3.csv',
    'GAVD_Clinical_Annotations_4.csv',
    'GAVD_Clinical_Annotations_5.csv'
]

print("🔍 Processing annotation files to extract sequence information...")

# Dictionary to store sequence info: {seq_id: {video_id, start_frame, end_frame, metadata}}
sequences_info = {}
video_sequences = defaultdict(list)  # Group sequences by video_id

for filename in annotation_files:
    filepath = os.path.join(data_dir, filename)
    print(f"📁 Loading {filename}...")
    
    try:
        df_temp = pd.read_csv(filepath, low_memory=False)
        
        # Group by sequence ID to get frame ranges
        for seq_id, seq_group in df_temp.groupby('seq'):
            if pd.isna(seq_id):
                continue
                
            video_id = seq_group['id'].iloc[0]
            if pd.isna(video_id):
                continue
                
            # Get frame range for this sequence
            start_frame = seq_group['frame_num'].min()
            end_frame = seq_group['frame_num'].max()
            
            # Store sequence metadata
            sequences_info[seq_id] = {
                'video_id': video_id,
                'start_frame': start_frame,
                'end_frame': end_frame,
                'gait_pat': seq_group['gait_pat'].iloc[0],
                'cam_view': seq_group['cam_view'].iloc[0],
                'dataset': seq_group['dataset'].iloc[0],
                'source_file': filename,
                'frame_count': end_frame - start_frame + 1
            }
            
            video_sequences[video_id].append(seq_id)
        
        print(f"   ✓ Processed {len(df_temp['seq'].unique())} sequences from {filename}")
        
    except Exception as e:
        print(f"   ❌ Error processing {filename}: {e}")

print(f"\n📊 SEQUENCE SUMMARY:")
print(f"Total sequences found: {len(sequences_info)}")
print(f"Videos with sequences: {len(video_sequences)}")

# Show sample sequences
print(f"\n📋 Sample sequences:")
sample_seqs = list(sequences_info.items())[:5]
for seq_id, info in sample_seqs:
    print(f"  • {seq_id}: {info['video_id']} frames {info['start_frame']}-{info['end_frame']} ({info['gait_pat']})")

# Check which sequences already exist
existing_sequences = set()
for seq_file in glob.glob(os.path.join(sequences_dir, "*.mp4")):
    seq_name = os.path.splitext(os.path.basename(seq_file))[0]
    existing_sequences.add(seq_name)

sequences_to_process = {k: v for k, v in sequences_info.items() if k not in existing_sequences}

print(f"\n🔄 PROCESSING STATUS:")
print(f"Already processed: {len(existing_sequences)} sequences")
print(f"To be processed: {len(sequences_to_process)} sequences")

if len(sequences_to_process) == 0:
    print("✅ All sequences have already been processed!")
else:
    print(f"\n⚠️  This will process {len(sequences_to_process)} sequences.")
    print("💡 TIP: You can interrupt the process anytime with Ctrl+C")

# Function to get video frame rate and duration
def get_video_info(video_path):
    """Get video information using ffprobe"""
    try:
        cmd = [
            'ffprobe', '-v', 'quiet', '-print_format', 'json', '-show_streams', video_path
        ]
        result = subprocess.run(cmd, capture_output=True, text=True, check=True)
        data = json.loads(result.stdout)
        
        for stream in data['streams']:
            if stream['codec_type'] == 'video':
                fps_str = stream.get('r_frame_rate', '30/1')
                fps = eval(fps_str) if '/' in fps_str else float(fps_str)
                duration = float(stream.get('duration', 0))
                return fps, duration
        return 30.0, 0.0  # Default values
    except Exception as e:
        print(f"   ⚠️  Could not get video info, using defaults: {e}")
        return 30.0, 0.0

# Function to extract sequence from video
def extract_sequence(video_path, seq_id, start_frame, end_frame, output_path):
    """Extract a sequence from video using ffmpeg"""
    try:
        # Get video info
        fps, duration = get_video_info(video_path)
        
        # Calculate time positions
        start_time = start_frame / fps
        end_time = end_frame / fps
        duration_seq = end_time - start_time
        
        # FFmpeg command to extract sequence
        cmd = [
            'ffmpeg', '-y',  # Overwrite output file
            '-i', video_path,
            '-ss', str(start_time),  # Start time
            '-t', str(duration_seq),  # Duration
            '-c:v', 'libx264',  # Video codec
            '-c:a', 'aac',  # Audio codec
            '-avoid_negative_ts', 'make_zero',
            output_path
        ]
        
        result = subprocess.run(cmd, capture_output=True, text=True, check=True)
        return True, ""
        
    except subprocess.CalledProcessError as e:
        return False, f"FFmpeg error: {e.stderr}"
    except Exception as e:
        return False, f"Error: {str(e)}"

# Check if ffmpeg is available
def check_ffmpeg():
    try:
        subprocess.run(['ffmpeg', '-version'], capture_output=True, check=True)
        return True
    except:
        return False

if not check_ffmpeg():
    print("❌ FFmpeg is not installed or not in PATH!")
    print("Please install FFmpeg to extract video sequences.")
    print("Download from: https://ffmpeg.org/download.html")
else:
    print("✅ FFmpeg is available")
    
    # Start sequence extraction
    if len(sequences_to_process) > 0:
        print(f"\n🚀 Starting sequence extraction...")
        
        processed_count = 0
        failed_count = 0
        failed_sequences = []
        
        for seq_id, seq_info in sequences_to_process.items():
            video_id = seq_info['video_id']
            start_frame = seq_info['start_frame']
            end_frame = seq_info['end_frame']
            gait_type = seq_info['gait_pat']
            
            # Find the downloaded video file (could be .mp4 or .webm)
            video_files = glob.glob(f"GAVD-videos/{video_id}.*")
            video_file = None
            
            # Prefer .mp4 files over .webm
            for vf in video_files:
                if vf.endswith('.mp4'):
                    video_file = vf
                    break
            if not video_file and video_files:
                video_file = video_files[0]  # Use any available file
            
            if not video_file:
                failed_count += 1
                failed_sequences.append((seq_id, f"Video file not found for {video_id}"))
                print(f"❌ [{processed_count+failed_count+1}/{len(sequences_to_process)}] {seq_id}: Video file not found")
                continue
            
            output_path = os.path.join(sequences_dir, f"{seq_id}.mp4")
            
            print(f"\n[{processed_count+failed_count+1}/{len(sequences_to_process)}] Extracting: {seq_id}")
            print(f"   Video: {video_id} ({gait_type})")
            print(f"   Frames: {start_frame}-{end_frame} ({seq_info['frame_count']} frames)")
            print(f"   Source: {os.path.basename(video_file)}")
            
            success, error = extract_sequence(video_file, seq_id, start_frame, end_frame, output_path)
            
            if success:
                processed_count += 1
                print(f"   ✅ Success! Saved to: {seq_id}.mp4")
                # delay for 1 second
                time.sleep(1)
            else:
                failed_count += 1
                failed_sequences.append((seq_id, error))
                print(f"   ❌ Failed: {error}")
        
        # Final summary
        print(f"\n🎉 SEQUENCE EXTRACTION COMPLETE!")
        print(f"✅ Successfully processed: {processed_count} sequences")
        print(f"❌ Failed extractions: {failed_count} sequences")
        
        if failed_sequences:
            print(f"\n📋 Failed sequences:")
            for seq_id, error in failed_sequences[:10]:  # Show first 10 failures
                print(f"  • {seq_id}: {error}")
            if len(failed_sequences) > 10:
                print(f"  ... and {len(failed_sequences) - 10} more failures")
        
        print(f"\n📁 All sequence videos are saved in: {sequences_dir}/")
        print("🔍 Each sequence is saved as: <sequence_id>.mp4")
        print("💡 Sequences are extracted based on frame numbers from the annotation data")
# Out:
# 🔍 Processing annotation files to extract sequence information...
# 📁 Loading GAVD_Clinical_Annotations_1.csv...
#    ✓ Processed 374 sequences from GAVD_Clinical_Annotations_1.csv
# 📁 Loading GAVD_Clinical_Annotations_2.csv...
#    ✓ Processed 353 sequences from GAVD_Clinical_Annotations_2.csv
# 📁 Loading GAVD_Clinical_Annotations_3.csv...
#    ✓ Processed 369 sequences from GAVD_Clinical_Annotations_3.csv
# 📁 Loading GAVD_Clinical_Annotations_4.csv...
#    ✓ Processed 313 sequences from GAVD_Clinical_Annotations_4.csv
# 📁 Loading GAVD_Clinical_Annotations_5.csv...
#    ✓ Processed 469 sequences from GAVD_Clinical_Annotations_5.csv
#
# 📊 SEQUENCE SUMMARY:
# Total sequences found: 1874
# Videos with sequences: 348
#
# 📋 Sample sequences:
#   • cljan9b4p00043n6ligceanyp: B5hrxKe2nP8 frames 1757-2268 (parkinsons)
#   • cljanb45y00083n6lmh1qhydd: B5hrxKe2nP8 frames 2532-2746 (parkinsons)
#   • cljao8kyf000d3n6l0x9kgmav: TgkxrrhnvlM frames 1-148 (abnormal)
#   • cljaoak47000i3n6lsrb9rit9: TgkxrrhnvlM frames 205-355 (abnormal)
#   • cljaob36l000m3n6l9xokjqww: TgkxrrhnvlM frames 382-813 (abnormal)
#
# 🔄 PROCESSING STATUS:
# Already processed: 491 sequences
# To be processed: 1383 sequences
#
# ⚠️  This will process 1383 sequences.
# 💡 TIP: You can interrupt the process anytime with Ctrl+C
# ✅ FFmpeg is available
#
# 🚀 Starting sequence extraction...
# ❌ [2/1383] cljapdtb500593n6leoif0c32: Video file not found
# ❌ [3/1383] cljapf2uw005d3n6lyasg3pn2: Video file not found
# ❌ [4/1383] cljapfx0p005h3n6lkhemkjqe: Video file not found
# ❌ [5/1383] cljapgo97005l3n6lbcz5g88s: Video file not found
# ❌ [6/1383] cljaphipu005p3n6lde8gqkl7: Video file not found
# ❌ [7/1383] cljapigcs005t3n6lrszkuyo2: Video file not found
# ❌ [8/1383] cljapjdrt005x3n6lpw9b8d9p: Video file not found
# ❌ [9/1383] cljapkbp500613n6lnp0i73x0: Video file not found
# ❌ [10/1383] cljapl0g800653n6lqbg2u3dy: Video file not found
# ❌ [11/1383] cljaplu8s00693n6ln0wqsmw9: Video file not found
# ❌ [12/1383] cljapmoo4006d3n6lxdm4mgtx: Video file not found
# ❌ [13/1383] cljapndqf006h3n6l7e4lfgab: Video file not found
# ❌ [14/1383] cljapo4ik006l3n6lut25j34h: Video file not found
# ❌ [15/1383] cljapowv3006p3n6l5y18z6yd: Video file not found
# ❌ [16/1383] cljappm1f006t3n6luyx9fn7x: Video file not found
# ❌ [17/1383] cljapq6hu006x3n6lhv8a2sxi: Video file not found
# ❌ [18/1383] cljapra6y00713n6l1pnc2dcp: Video file not found
# ❌ [19/1383] cljapshca00753n6lx3zxny7g: Video file not found
# ❌ [20/1383] cljaptbhz00793n6lttmx1m9q: Video file not found
# ❌ [21/1383] cljapufzd007d3n6la5hnnij9: Video file not found
# ❌ [22/1383] cljapveob007h3n6lzxwbwq40: Video file not found
# ❌ [23/1383] cljapw5z9007o3n6lx3gdpodt: Video file not found
# ❌ [24/1383] cljapx1to007s3n6l6fnneyz7: Video file not found
# ❌ [25/1383] cljapxthz007w3n6l8asb771a: Video file not found
# ❌ [26/1383] cljapynp700803n6ln0u4afvp: Video file not found
# ❌ [27/1383] cljapzqjr00843n6l6u65dfzi: Video file not found
# ❌ [28/1383] cljaq0nri00883n6l3raldiuo: Video file not found
# ❌ [29/1383] cljaq18rc008c3n6l6c3135e0: Video file not found
# ❌ [30/1383] cljaq23dz008g3n6lwkqgwsuc: Video file not found
# ❌ [31/1383] cljaq2u1q008k3n6llu4yrcwl: Video file not found
# ❌ [32/1383] cljaq400n008o3n6ls76k3nvx: Video file not found
# ❌ [33/1383] cljaq4pam008s3n6liq2iebvy: Video file not found
# ❌ [34/1383] cljaq5p9e008w3n6lpfhus2j4: Video file not found
# ❌ [35/1383] cljaq6l3400903n6l2dpbfyqp: Video file not found
#
# [35/1383] Extracting: cljvx8zo5004j3n6l09nz7rpt
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 6087-6285 (199 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvx8zo5004j3n6l09nz7rpt.mp4
#
# [36/1383] Extracting: cljvx9oz1004n3n6lq7ax9uzr
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 6328-6514 (187 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvx9oz1004n3n6lq7ax9uzr.mp4
#
# [37/1383] Extracting: cljvxal6r004r3n6lykfghhom
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 6580-6761 (182 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxal6r004r3n6lykfghhom.mp4
#
# [38/1383] Extracting: cljvxbmbq004v3n6lz5ou4j62
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 7017-7341 (325 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxbmbq004v3n6lz5ou4j62.mp4
#
# [39/1383] Extracting: cljvxcwbz004z3n6lmavy9xwl
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 7380-7414 (35 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxcwbz004z3n6lmavy9xwl.mp4
#
# [40/1383] Extracting: cljvxduqs00533n6ly46hzkk8
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 7487-7837 (351 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxduqs00533n6ly46hzkk8.mp4
#
# [41/1383] Extracting: cljvxflwd00573n6lpn9dt7mc
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 7917-7937 (21 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxflwd00573n6lpn9dt7mc.mp4
#
# [42/1383] Extracting: cljvxgo1n005b3n6l1bw4vydg
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 9176-9243 (68 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxgo1n005b3n6l1bw4vydg.mp4
#
# [43/1383] Extracting: cljvxhzpm005f3n6lup499agk
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 9656-9866 (211 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxhzpm005f3n6lup499agk.mp4
#
# [44/1383] Extracting: cljvxijr4005i3n6l51ll5c0g
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 9912-10103 (192 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxijr4005i3n6l51ll5c0g.mp4
#
# [45/1383] Extracting: cljvxjkga005m3n6llroca6j3
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 10641-11133 (493 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxjkga005m3n6llroca6j3.mp4
#
# [46/1383] Extracting: cljvxkgf9005q3n6ls1lts5ug
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 11325-11491 (167 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxkgf9005q3n6ls1lts5ug.mp4
#
# [47/1383] Extracting: cljvxl9n3005u3n6lqtp6f009
#    Video: AWS_zIFfGTg (abnormal)
#    Frames: 11883-11982 (100 frames)
#    Source: AWS_zIFfGTg.mp4
#    ✅ Success! Saved to: cljvxl9n3005u3n6lqtp6f009.mp4
#
# [48/1383] Extracting: cljw2m5z500043n6lddrtk80j
#    Video: AxImjrl7l_U (inebriated)
#    Frames: 1-286 (286 frames)
#    Source: AxImjrl7l_U.mp4
#    ✅ Success! Saved to: cljw2m5z500043n6lddrtk80j.mp4
#
# [49/1383] Extracting: cljw2ochy00083n6l3ry9cvgy
#    Video: AxImjrl7l_U (inebriated)
#    Frames: 353-1002 (650 frames)
#    Source: AxImjrl7l_U.mp4
#    ✅ Success! Saved to: cljw2ochy00083n6l3ry9cvgy.mp4
#
# [50/1383] Extracting: cljw2tyvf000c3n6ln2i5ydos
#    Video: AxImjrl7l_U (inebriated)
#    Frames: 1292-1549 (258 frames)
#    Source: AxImjrl7l_U.mp4
#    ✅ Success! Saved to: cljw2tyvf000c3n6ln2i5ydos.mp4
#
# [51/1383] Extracting: cljw2uzhq000g3n6l4hha2c1e
#    Video: AxImjrl7l_U (inebriated)
#    Frames: 1677-2031 (355 frames)
#    Source: AxImjrl7l_U.mp4
#    ✅ Success! Saved to: cljw2uzhq000g3n6l4hha2c1e.mp4
#
# [52/1383] Extracting: cljw2vl73000k3n6lqkzk2mga
#    Video: AxImjrl7l_U (inebriated)
#    Frames: 2137-2988 (852 frames)
#    Source: AxImjrl7l_U.mp4
#    ✅ Success! Saved to: cljw2vl73000k3n6lqkzk2mga.mp4
#
# [53/1383] Extracting: cljw2wxoy000o3n6lby0fknus
#    Video: AxImjrl7l_U (inebriated)
#    Frames: 3163-3297 (135 frames)
#    Source: AxImjrl7l_U.mp4
#    ✅ Success! Saved to: cljw2wxoy000o3n6lby0fknus.mp4
#
# [54/1383] Extracting: cljw2z31s000w3n6lni7ls140
#    Video: AxImjrl7l_U (inebriated)
#    Frames: 4886-5053 (168 frames)
#    Source: AxImjrl7l_U.mp4
#    ✅ Success! Saved to: cljw2z31s000w3n6lni7ls140.mp4
#
# [55/1383] Extracting: cljw30e2700143n6lx5ba2sma
#    Video: AxImjrl7l_U (inebriated)
#    Frames: 5460-5812 (353 frames)
#    Source: AxImjrl7l_U.mp4
#    ✅ Success! Saved to: cljw30e2700143n6lx5ba2sma.mp4
#
# [56/1383] Extracting: cljw3xegk00043n6l9kkmoeco
#    Video: b0ljTBGJWnw (exercise)
#    Frames: 78-392 (315 frames)
#    Source: b0ljTBGJWnw.mp4
#    ✅ Success! Saved to: cljw3xegk00043n6l9kkmoeco.mp4
#
# [57/1383] Extracting: cljw3yogu00093n6lsap57tt4
#    Video: b2n0USprXmQ (prosthetic)
#    Frames: 224-869 (646 frames)
#    Source: b2n0USprXmQ.mp4
#    ✅ Success! Saved to: cljw3yogu00093n6lsap57tt4.mp4
#
# [58/1383] Extracting: cljw3ziud000d3n6lavym94ol
#    Video: b2n0USprXmQ (prosthetic)
#    Frames: 874-1304 (431 frames)
#    Source: b2n0USprXmQ.mp4
#    ✅ Success! Saved to: cljw3ziud000d3n6lavym94ol.mp4
#
# [59/1383] Extracting: cljw3zyxa000h3n6lrlj0pgvo
#    Video: b2n0USprXmQ (prosthetic)
#    Frames: 1318-1875 (558 frames)
#    Source: b2n0USprXmQ.mp4
#    ✅ Success! Saved to: cljw3zyxa000h3n6lrlj0pgvo.mp4
#
# [60/1383] Extracting: cljw40lsw000l3n6l0mit7gid
#    Video: b2n0USprXmQ (prosthetic)
#    Frames: 1885-2248 (364 frames)
#    Source: b2n0USprXmQ.mp4
#    ✅ Success! Saved to: cljw40lsw000l3n6l0mit7gid.mp4
#
# [61/1383] Extracting: cljw413ht000p3n6l2nrixlh6
#    Video: b2n0USprXmQ (prosthetic)
#    Frames: 2256-2393 (138 frames)
#    Source: b2n0USprXmQ.mp4
#    ✅ Success! Saved to: cljw413ht000p3n6l2nrixlh6.mp4
#
# [62/1383] Extracting: cljw4219w000t3n6lid99z8il
#    Video: b2n0USprXmQ (prosthetic)
#    Frames: 2843-3102 (260 frames)
#    Source: b2n0USprXmQ.mp4
#    ✅ Success! Saved to: cljw4219w000t3n6lid99z8il.mp4
#
# [63/1383] Extracting: cljw42r0i000x3n6lqcqfmipc
#    Video: b2n0USprXmQ (prosthetic)
#    Frames: 3111-3328 (218 frames)
#    Source: b2n0USprXmQ.mp4
#    ✅ Success! Saved to: cljw42r0i000x3n6lqcqfmipc.mp4
#
# [64/1383] Extracting: cljw43jb900123n6lewjt9vqg
#    Video: B3ohGeUR0XY (exercise)
#    Frames: 41-255 (215 frames)
#    Source: B3ohGeUR0XY.mp4
#    ✅ Success! Saved to: cljw43jb900123n6lewjt9vqg.mp4
#
# [65/1383] Extracting: cljw448vx00163n6lhm5vmfhm
#    Video: B3ohGeUR0XY (exercise)
#    Frames: 298-506 (209 frames)
#    Source: B3ohGeUR0XY.mp4
#    ✅ Success! Saved to: cljw448vx00163n6lhm5vmfhm.mp4
#
# [66/1383] Extracting: cljw456fl001b3n6lgrikkdsg
#    Video: B4rOTkTPbMI (stroke)
#    Frames: 87-194 (108 frames)
#    Source: B4rOTkTPbMI.mp4
#    ✅ Success! Saved to: cljw456fl001b3n6lgrikkdsg.mp4
#
# [67/1383] Extracting: cljw461m9001f3n6l0o9gjzvg
#    Video: B4rOTkTPbMI (stroke)
#    Frames: 262-388 (127 frames)
#    Source: B4rOTkTPbMI.mp4
#    ✅ Success! Saved to: cljw461m9001f3n6l0o9gjzvg.mp4
#
# [68/1383] Extracting: cljw46iz7001k3n6ln8mclrmb
#    Video: b7VSPvw4FvE (exercise)
#    Frames: 1-219 (219 frames)
#    Source: b7VSPvw4FvE.mp4
#    ✅ Success! Saved to: cljw46iz7001k3n6ln8mclrmb.mp4
#
# [69/1383] Extracting: cljw47neo001o3n6ll8fh5krg
#    Video: b7VSPvw4FvE (exercise)
#    Frames: 294-491 (198 frames)
#    Source: b7VSPvw4FvE.mp4
#    ✅ Success! Saved to: cljw47neo001o3n6ll8fh5krg.mp4
#
# [70/1383] Extracting: cljw488gl001t3n6l5ogfho3h
#    Video: b46xmMgdtnY (abnormal)
#    Frames: 1-138 (138 frames)
#    Source: b46xmMgdtnY.mp4
#    ✅ Success! Saved to: cljw488gl001t3n6l5ogfho3h.mp4
#
# [71/1383] Extracting: cljw48sqo001x3n6lui1j6arn
#    Video: b46xmMgdtnY (abnormal)
#    Frames: 178-303 (126 frames)
#    Source: b46xmMgdtnY.mp4
#    ✅ Success! Saved to: cljw48sqo001x3n6lui1j6arn.mp4
#
# [72/1383] Extracting: cljw498vp00213n6lke1u98jj
#    Video: b46xmMgdtnY (abnormal)
#    Frames: 357-489 (133 frames)
#    Source: b46xmMgdtnY.mp4
#    ✅ Success! Saved to: cljw498vp00213n6lke1u98jj.mp4
#
# [73/1383] Extracting: cljw4a7sh00263n6l26jwdqpf
#    Video: BGMTJ8NJAxA (prosthetic)
#    Frames: 1-453 (453 frames)
#    Source: BGMTJ8NJAxA.mp4
#    ✅ Success! Saved to: cljw4a7sh00263n6l26jwdqpf.mp4
#
# [74/1383] Extracting: cljw4az3t002a3n6l7j3i4lee
#    Video: BGMTJ8NJAxA (prosthetic)
#    Frames: 506-914 (409 frames)
#    Source: BGMTJ8NJAxA.mp4
#    ✅ Success! Saved to: cljw4az3t002a3n6l7j3i4lee.mp4
#
# [75/1383] Extracting: cljw4bg4q002e3n6lkugx2mrd
#    Video: BGMTJ8NJAxA (prosthetic)
#    Frames: 932-1920 (989 frames)
#    Source: BGMTJ8NJAxA.mp4
#    ✅ Success! Saved to: cljw4bg4q002e3n6lkugx2mrd.mp4
#
# [76/1383] Extracting: cljw4bvwa002i3n6l11cwtwxq
#    Video: BGMTJ8NJAxA (prosthetic)
#    Frames: 1982-3014 (1033 frames)
#    Source: BGMTJ8NJAxA.mp4
#    ✅ Success! Saved to: cljw4bvwa002i3n6l11cwtwxq.mp4
#
# [77/1383] Extracting: cljw614kh002n3n6l98x3nnr6
#    Video: bmi1hYOnTHs (parkinsons)
#    Frames: 147-333 (187 frames)
#    Source: bmi1hYOnTHs.mp4
#    ✅ Success! Saved to: cljw614kh002n3n6l98x3nnr6.mp4
#
# [78/1383] Extracting: cljw61mqp002r3n6ly9axf1b2
#    Video: bmi1hYOnTHs (parkinsons)
#    Frames: 363-459 (97 frames)
#    Source: bmi1hYOnTHs.mp4
#    ✅ Success! Saved to: cljw61mqp002r3n6ly9axf1b2.mp4
#
# [79/1383] Extracting: cljw6392x002v3n6l2cmbbtj8
#    Video: bmi1hYOnTHs (parkinsons)
#    Frames: 758-922 (165 frames)
#    Source: bmi1hYOnTHs.mp4
#    ✅ Success! Saved to: cljw6392x002v3n6l2cmbbtj8.mp4
#
# [80/1383] Extracting: cljw63z1r002z3n6ls929nezr
#    Video: bmi1hYOnTHs (parkinsons)
#    Frames: 2198-2274 (77 frames)
#    Source: bmi1hYOnTHs.mp4
#    ✅ Success! Saved to: cljw63z1r002z3n6ls929nezr.mp4
#
# [81/1383] Extracting: cljw65m0800333n6lpxsiegdj
#    Video: bmi1hYOnTHs (parkinsons)
#    Frames: 2745-3233 (489 frames)
#    Source: bmi1hYOnTHs.mp4
#    ✅ Success! Saved to: cljw65m0800333n6lpxsiegdj.mp4
#
# [82/1383] Extracting: cljw66tru00363n6lul1gvz3v
#    Video: bmi1hYOnTHs (parkinsons)
#    Frames: 3825-4177 (353 frames)
#    Source: bmi1hYOnTHs.mp4
#    ✅ Success! Saved to: cljw66tru00363n6lul1gvz3v.mp4
#
# [83/1383] Extracting: cljw69f3h003a3n6lk2qd3f08
#    Video: bmi1hYOnTHs (parkinsons)
#    Frames: 5413-5707 (295 frames)
#    Source: bmi1hYOnTHs.mp4
#    ✅ Success! Saved to: cljw69f3h003a3n6lk2qd3f08.mp4
#
# [84/1383] Extracting: cljw6a6on003e3n6l34f95ehd
#    Video: bmi1hYOnTHs (parkinsons)
#    Frames: 6401-6521 (121 frames)
#    Source: bmi1hYOnTHs.mp4
#    ✅ Success! Saved to: cljw6a6on003e3n6l34f95ehd.mp4
#
# [85/1383] Extracting: cljw6dlqu00043n6lth228e1x
#    Video: By95MlAGTjE (abnormal)
#    Frames: 20-144 (125 frames)
#    Source: By95MlAGTjE.mp4
#    ✅ Success! Saved to: cljw6dlqu00043n6lth228e1x.mp4
#
# [86/1383] Extracting: cljw6e97y00083n6lopyf3zqt
#    Video: By95MlAGTjE (abnormal)
#    Frames: 190-266 (77 frames)
#    Source: By95MlAGTjE.mp4
#    ✅ Success! Saved to: cljw6e97y00083n6lopyf3zqt.mp4
#
# [87/1383] Extracting: cljw6f07a000c3n6l2ayhqj3o
#    Video: By95MlAGTjE (abnormal)
#    Frames: 274-375 (102 frames)
#    Source: By95MlAGTjE.mp4
#    ✅ Success! Saved to: cljw6f07a000c3n6l2ayhqj3o.mp4
#
# [88/1383] Extracting: cljw6gacy000g3n6lot0jsum0
#    Video: By95MlAGTjE (abnormal)
#    Frames: 691-727 (37 frames)
#    Source: By95MlAGTjE.mp4
#    ✅ Success! Saved to: cljw6gacy000g3n6lot0jsum0.mp4
#
# [89/1383] Extracting: cljw6hftm000k3n6l1whdg71z
#    Video: By95MlAGTjE (abnormal)
#    Frames: 947-994 (48 frames)
#    Source: By95MlAGTjE.mp4
#    ✅ Success! Saved to: cljw6hftm000k3n6l1whdg71z.mp4
#
# [90/1383] Extracting: cljw6hu10000o3n6l4cmx3ypi
#    Video: By95MlAGTjE (abnormal)
#    Frames: 996-1038 (43 frames)
#    Source: By95MlAGTjE.mp4
#    ✅ Success! Saved to: cljw6hu10000o3n6l4cmx3ypi.mp4
#
# [91/1383] Extracting: cljw6ilc7000s3n6l6iyc9ju4
#    Video: By95MlAGTjE (abnormal)
#    Frames: 1043-1083 (41 frames)
#    Source: By95MlAGTjE.mp4
#    ✅ Success! Saved to: cljw6ilc7000s3n6l6iyc9ju4.mp4
#
# [92/1383] Extracting: cljw6jpnw000w3n6lvibo5ynh
#    Video: By95MlAGTjE (abnormal)
#    Frames: 1471-1564 (94 frames)
#    Source: By95MlAGTjE.mp4
#    ✅ Success! Saved to: cljw6jpnw000w3n6lvibo5ynh.mp4
#
# [93/1383] Extracting: cljw6khdg00103n6ljsgnaaq3
#    Video: By95MlAGTjE (abnormal)
#    Frames: 1819-1882 (64 frames)
#    Source: By95MlAGTjE.mp4
#    ✅ Success! Saved to: cljw6khdg00103n6ljsgnaaq3.mp4
#
# [94/1383] Extracting: cljw6n7mg00173n6lnk3lmru5
#    Video: cAETIJSUobY (exercise)
#    Frames: 14-228 (215 frames)
#    Source: cAETIJSUobY.mp4
#    ✅ Success! Saved to: cljw6n7mg00173n6lnk3lmru5.mp4
#
# [95/1383] Extracting: cljw6nqn7001b3n6liypqmvgj
#    Video: cAETIJSUobY (exercise)
#    Frames: 360-631 (272 frames)
#    Source: cAETIJSUobY.mp4
#    ✅ Success! Saved to: cljw6nqn7001b3n6liypqmvgj.mp4
#
# [96/1383] Extracting: cljw6om0e001f3n6l395dmbg4
#    Video: cAETIJSUobY (exercise)
#    Frames: 746-1008 (263 frames)
#    Source: cAETIJSUobY.mp4
#    ✅ Success! Saved to: cljw6om0e001f3n6l395dmbg4.mp4
#
# [97/1383] Extracting: cljw6phvc001k3n6l65kgd53c
#    Video: cegLAYxNO1E (exercise)
#    Frames: 70-309 (240 frames)
#    Source: cegLAYxNO1E.mp4
#    ✅ Success! Saved to: cljw6phvc001k3n6l65kgd53c.mp4
#
# [98/1383] Extracting: cljw6qeiv001o3n6lo9dcmmeg
#    Video: cegLAYxNO1E (exercise)
#    Frames: 331-551 (221 frames)
#    Source: cegLAYxNO1E.mp4
#    ✅ Success! Saved to: cljw6qeiv001o3n6lo9dcmmeg.mp4
#
# [99/1383] Extracting: cljw6r61s001t3n6luv0xuqsw
#    Video: Ci73SIVET50 (inebriated)
#    Frames: 314-462 (149 frames)
#    Source: Ci73SIVET50.mp4
#    ✅ Success! Saved to: cljw6r61s001t3n6luv0xuqsw.mp4
#
# [100/1383] Extracting: cljw6rump001x3n6lutuft47b
#    Video: Ci73SIVET50 (inebriated)
#    Frames: 556-604 (49 frames)
#    Source: Ci73SIVET50.mp4
#    ✅ Success! Saved to: cljw6rump001x3n6lutuft47b.mp4
#
# [101/1383] Extracting: cljw6sanb00213n6lzcmw192b
#    Video: Ci73SIVET50 (inebriated)
#    Frames: 639-871 (233 frames)
#    Source: Ci73SIVET50.mp4
#    ✅ Success! Saved to: cljw6sanb00213n6lzcmw192b.mp4
#
# [102/1383] Extracting: cljw6t22j00253n6lqj29g2uu
#    Video: Ci73SIVET50 (inebriated)
#    Frames: 1078-1157 (80 frames)
#    Source: Ci73SIVET50.mp4
#    ✅ Success! Saved to: cljw6t22j00253n6lqj29g2uu.mp4
#
# [103/1383] Extracting: cljw6tpgu00293n6lhjzerp7d
#    Video: Ci73SIVET50 (inebriated)
#    Frames: 1187-1278 (92 frames)
#    Source: Ci73SIVET50.mp4
#    ✅ Success! Saved to: cljw6tpgu00293n6lhjzerp7d.mp4
#
# [104/1383] Extracting: cljw6u6lf002d3n6lo0tu78zp
#    Video: Ci73SIVET50 (inebriated)
#    Frames: 1280-1361 (82 frames)
#    Source: Ci73SIVET50.mp4
#    ✅ Success! Saved to: cljw6u6lf002d3n6lo0tu78zp.mp4
#
# [105/1383] Extracting: cljw6utb3002i3n6ll0pspyhl
#    Video: CMls0LwK5OU (stroke)
#    Frames: 1-207 (207 frames)
#    Source: CMls0LwK5OU.mp4
#    ✅ Success! Saved to: cljw6utb3002i3n6ll0pspyhl.mp4
#
# [106/1383] Extracting: cljw6vv80002m3n6l14b2y4jg
#    Video: CMls0LwK5OU (stroke)
#    Frames: 493-715 (223 frames)
#    Source: CMls0LwK5OU.mp4
#    ✅ Success! Saved to: cljw6vv80002m3n6l14b2y4jg.mp4
#
# [107/1383] Extracting: cljw6wq8o002q3n6lo4lmi8vd
#    Video: CMls0LwK5OU (stroke)
#    Frames: 758-914 (157 frames)
#    Source: CMls0LwK5OU.mp4
#    ✅ Success! Saved to: cljw6wq8o002q3n6lo4lmi8vd.mp4
#
# [108/1383] Extracting: cljw6xyo3002u3n6lyl23l27l
#    Video: CMls0LwK5OU (stroke)
#    Frames: 1667-1955 (289 frames)
#    Source: CMls0LwK5OU.mp4
#    ✅ Success! Saved to: cljw6xyo3002u3n6lyl23l27l.mp4
#
# [109/1383] Extracting: cljw6yqg200313n6l6u9humd4
#    Video: CMls0LwK5OU (stroke)
#    Frames: 1958-2140 (183 frames)
#    Source: CMls0LwK5OU.mp4
#    ✅ Success! Saved to: cljw6yqg200313n6l6u9humd4.mp4
#
# [110/1383] Extracting: cljw6zrh800353n6l76psqelc
#    Video: cqbQi5BTsSw (abnormal)
#    Frames: 1-270 (270 frames)
#    Source: cqbQi5BTsSw.mp4
#    ✅ Success! Saved to: cljw6zrh800353n6l76psqelc.mp4
#
# [111/1383] Extracting: cljw70c2t00393n6l8ou5prmf
#    Video: cqbQi5BTsSw (abnormal)
#    Frames: 309-574 (266 frames)
#    Source: cqbQi5BTsSw.mp4
#    ✅ Success! Saved to: cljw70c2t00393n6l8ou5prmf.mp4
#
# [112/1383] Extracting: cljw70yj4003d3n6lzhjn55nb
#    Video: cqbQi5BTsSw (abnormal)
#    Frames: 590-1666 (1077 frames)
#    Source: cqbQi5BTsSw.mp4
#    ✅ Success! Saved to: cljw70yj4003d3n6lzhjn55nb.mp4
#
# [113/1383] Extracting: cljw7257w003h3n6lgnsitrvd
#    Video: cqbQi5BTsSw (abnormal)
#    Frames: 1805-2897 (1093 frames)
#    Source: cqbQi5BTsSw.mp4
#    ✅ Success! Saved to: cljw7257w003h3n6lgnsitrvd.mp4
#
# [114/1383] Extracting: cljw73je6003m3n6l9d63qd2a
#    Video: CrToYDUN89A (abnormal)
#    Frames: 291-389 (99 frames)
#    Source: CrToYDUN89A.mp4
#    ✅ Success! Saved to: cljw73je6003m3n6l9d63qd2a.mp4
#
# [115/1383] Extracting: cljw743d9003q3n6l8tpmdqtf
#    Video: CrToYDUN89A (abnormal)
#    Frames: 524-950 (427 frames)
#    Source: CrToYDUN89A.mp4
#    ✅ Success! Saved to: cljw743d9003q3n6l8tpmdqtf.mp4
#
# [116/1383] Extracting: cljw74mqw003u3n6lmj3h1v6x
#    Video: CrToYDUN89A (abnormal)
#    Frames: 1192-1580 (389 frames)
#    Source: CrToYDUN89A.mp4
#    ✅ Success! Saved to: cljw74mqw003u3n6lmj3h1v6x.mp4
#
# [117/1383] Extracting: cljw75out003z3n6ldarll2qz
#    Video: cWujgb8jHNE (myopathic)
#    Frames: 1-175 (175 frames)
#    Source: cWujgb8jHNE.mp4
#    ✅ Success! Saved to: cljw75out003z3n6ldarll2qz.mp4
#
# [118/1383] Extracting: cljw76g4e00443n6lfbboyczo
#    Video: dc7cnLxbpKU (stroke)
#    Frames: 1-164 (164 frames)
#    Source: dc7cnLxbpKU.mp4
#    ✅ Success! Saved to: cljw76g4e00443n6lfbboyczo.mp4
#
# [119/1383] Extracting: cljw771mg00483n6lnajrytho
#    Video: dc7cnLxbpKU (stroke)
#    Frames: 250-412 (163 frames)
#    Source: dc7cnLxbpKU.mp4
#    ✅ Success! Saved to: cljw771mg00483n6lnajrytho.mp4
#
# [120/1383] Extracting: cljw77snx004c3n6lvetndlu2
#    Video: dc7cnLxbpKU (stroke)
#    Frames: 421-570 (150 frames)
#    Source: dc7cnLxbpKU.mp4
#    ✅ Success! Saved to: cljw77snx004c3n6lvetndlu2.mp4
#
# [121/1383] Extracting: cljw78k2f004h3n6lsbwyu559
#    Video: DcHU3z0v63M (abnormal)
#    Frames: 2-131 (130 frames)
#    Source: DcHU3z0v63M.mp4
#    ✅ Success! Saved to: cljw78k2f004h3n6lsbwyu559.mp4
#
# [122/1383] Extracting: cljw79f1u004l3n6l6qctcevn
#    Video: DcHU3z0v63M (abnormal)
#    Frames: 216-450 (235 frames)
#    Source: DcHU3z0v63M.mp4
#    ✅ Success! Saved to: cljw79f1u004l3n6l6qctcevn.mp4
#
# [123/1383] Extracting: cljw7a2mf004q3n6l5u1wps0e
#    Video: ddMHjYSIQsM (exercise)
#    Frames: 1-200 (200 frames)
#    Source: ddMHjYSIQsM.mp4
#    ✅ Success! Saved to: cljw7a2mf004q3n6l5u1wps0e.mp4
#
# [124/1383] Extracting: cljw7ajrd004u3n6ltrzrbk92
#    Video: ddMHjYSIQsM (exercise)
#    Frames: 273-478 (206 frames)
#    Source: ddMHjYSIQsM.mp4
#    ✅ Success! Saved to: cljw7ajrd004u3n6ltrzrbk92.mp4
#
# [125/1383] Extracting: cljw7c11f004z3n6ldnwe9cqj
#    Video: d-jXLtMnqGY (exercise)
#    Frames: 486-637 (152 frames)
#    Source: d-jXLtMnqGY.mp4
#    ✅ Success! Saved to: cljw7c11f004z3n6ldnwe9cqj.mp4
#
# [126/1383] Extracting: cljw7cy8n00573n6logmpj8qf
#    Video: d-jXLtMnqGY (exercise)
#    Frames: 732-847 (116 frames)
#    Source: d-jXLtMnqGY.mp4
#    ✅ Success! Saved to: cljw7cy8n00573n6logmpj8qf.mp4
#
# [127/1383] Extracting: cljw7drsi005f3n6l5aaw5d6j
#    Video: d-jXLtMnqGY (exercise)
#    Frames: 1024-1135 (112 frames)
#    Source: d-jXLtMnqGY.mp4
#    ✅ Success! Saved to: cljw7drsi005f3n6l5aaw5d6j.mp4
#
# [128/1383] Extracting: cljw7ewnf005o3n6ltnxeqg54
#    Video: DnPpm_VKqhI (exercise)
#    Frames: 103-406 (304 frames)
#    Source: DnPpm_VKqhI.mp4
#    ✅ Success! Saved to: cljw7ewnf005o3n6ltnxeqg54.mp4
#
# [129/1383] Extracting: cljw7gpfm005t3n6lfh2c2fbe
#    Video: Duy4Y8vRZ0I (abnormal)
#    Frames: 29-218 (190 frames)
#    Source: Duy4Y8vRZ0I.mp4
#    ✅ Success! Saved to: cljw7gpfm005t3n6lfh2c2fbe.mp4
#
# [130/1383] Extracting: cljw7hh02005x3n6lt2o9ycfs
#    Video: Duy4Y8vRZ0I (abnormal)
#    Frames: 273-457 (185 frames)
#    Source: Duy4Y8vRZ0I.mp4
#    ✅ Success! Saved to: cljw7hh02005x3n6lt2o9ycfs.mp4
#
# [131/1383] Extracting: cljw7jxyk00663n6la0rfq89w
#    Video: dvfeYnWVD08 (stroke)
#    Frames: 380-464 (85 frames)
#    Source: dvfeYnWVD08.mp4
#    ✅ Success! Saved to: cljw7jxyk00663n6la0rfq89w.mp4
#
# [132/1383] Extracting: cljw7knmw006a3n6lz5gfb0bo
#    Video: dvfeYnWVD08 (stroke)
#    Frames: 474-700 (227 frames)
#    Source: dvfeYnWVD08.mp4
#    ✅ Success! Saved to: cljw7knmw006a3n6lz5gfb0bo.mp4
#
# [133/1383] Extracting: cljw7lvm6006f3n6lme1qtv2g
#    Video: dXAvAA556gE (cerebral palsy)
#    Frames: 758-836 (79 frames)
#    Source: dXAvAA556gE.mp4
#    ✅ Success! Saved to: cljw7lvm6006f3n6lme1qtv2g.mp4
#
# [134/1383] Extracting: cljw7mjyv006j3n6lr6d34gvu
#    Video: dXAvAA556gE (cerebral palsy)
#    Frames: 858-912 (55 frames)
#    Source: dXAvAA556gE.mp4
#    ✅ Success! Saved to: cljw7mjyv006j3n6lr6d34gvu.mp4
#
# [135/1383] Extracting: cljw7ndde006n3n6lfm5x8fuv
#    Video: dXAvAA556gE (cerebral palsy)
#    Frames: 1210-1441 (232 frames)
#    Source: dXAvAA556gE.mp4
#    ✅ Success! Saved to: cljw7ndde006n3n6lfm5x8fuv.mp4
#
# [136/1383] Extracting: cljw7orya006s3n6lopenf75e
#    Video: dxRMtNtjwCc (parkinsons)
#    Frames: 685-1335 (651 frames)
#    Source: dxRMtNtjwCc.mp4
#    ✅ Success! Saved to: cljw7orya006s3n6lopenf75e.mp4
#
# [137/1383] Extracting: cljw7pk60006w3n6lud1dvft9
#    Video: dxRMtNtjwCc (parkinsons)
#    Frames: 1347-1603 (257 frames)
#    Source: dxRMtNtjwCc.mp4
#    ✅ Success! Saved to: cljw7pk60006w3n6lud1dvft9.mp4
#
# [138/1383] Extracting: cljw7q1kn00703n6lo6plljo9
#    Video: dxRMtNtjwCc (parkinsons)
#    Frames: 1894-2224 (331 frames)
#    Source: dxRMtNtjwCc.mp4
#    ✅ Success! Saved to: cljw7q1kn00703n6lo6plljo9.mp4
#
# [139/1383] Extracting: cljw7r04700753n6ljc4jrdyl
#    Video: eBvzFkcvScg (stroke)
#    Frames: 27-92 (66 frames)
#    Source: eBvzFkcvScg.mp4
#    ✅ Success! Saved to: cljw7r04700753n6ljc4jrdyl.mp4
#
# [140/1383] Extracting: cljw7rexn00793n6l1q6fmh8e
#    Video: eBvzFkcvScg (stroke)
#    Frames: 116-191 (76 frames)
#    Source: eBvzFkcvScg.mp4
#    ✅ Success! Saved to: cljw7rexn00793n6l1q6fmh8e.mp4
#
# [141/1383] Extracting: cljw7rzbm007d3n6lanxu4gf4
#    Video: eBvzFkcvScg (stroke)
#    Frames: 222-277 (56 frames)
#    Source: eBvzFkcvScg.mp4
#    ✅ Success! Saved to: cljw7rzbm007d3n6lanxu4gf4.mp4
#
# [142/1383] Extracting: cljw7shbo007h3n6lhj6j73z3
#    Video: eBvzFkcvScg (stroke)
#    Frames: 308-365 (58 frames)
#    Source: eBvzFkcvScg.mp4
#    ✅ Success! Saved to: cljw7shbo007h3n6lhj6j73z3.mp4
#
# [143/1383] Extracting: cljw7swdz007l3n6larz6jybg
#    Video: eBvzFkcvScg (stroke)
#    Frames: 398-445 (48 frames)
#    Source: eBvzFkcvScg.mp4
#    ✅ Success! Saved to: cljw7swdz007l3n6larz6jybg.mp4
#
# [144/1383] Extracting: cljw7tfqg007p3n6l0nwqb8w1
#    Video: eBvzFkcvScg (stroke)
#    Frames: 478-569 (92 frames)
#    Source: eBvzFkcvScg.mp4
#    ✅ Success! Saved to: cljw7tfqg007p3n6l0nwqb8w1.mp4
#
# [145/1383] Extracting: cljw7u9tn007u3n6lq4pt7x51
#    Video: eC5rBFti78M (exercise)
#    Frames: 221-384 (164 frames)
#    Source: eC5rBFti78M.mp4
#    ✅ Success! Saved to: cljw7u9tn007u3n6lq4pt7x51.mp4
#
# [146/1383] Extracting: cljw7uo8h007y3n6lyok5axbw
#    Video: eC5rBFti78M (exercise)
#    Frames: 433-564 (132 frames)
#    Source: eC5rBFti78M.mp4
#    ✅ Success! Saved to: cljw7uo8h007y3n6lyok5axbw.mp4
#
# [147/1383] Extracting: cljwbcjvq00043n6lllxhr535
#    Video: EjPUpKUbZSg (abnormal)
#    Frames: 1-307 (307 frames)
#    Source: EjPUpKUbZSg.mp4
#    ✅ Success! Saved to: cljwbcjvq00043n6lllxhr535.mp4
#
# [148/1383] Extracting: cljwbdhda00093n6lz1d59m25
#    Video: eOe2AgVK5xI (abnormal)
#    Frames: 455-605 (151 frames)
#    Source: eOe2AgVK5xI.mp4
#    ✅ Success! Saved to: cljwbdhda00093n6lz1d59m25.mp4
#
# [149/1383] Extracting: cljwbentj000d3n6lkdzqc77e
#    Video: eOe2AgVK5xI (abnormal)
#    Frames: 791-1042 (252 frames)
#    Source: eOe2AgVK5xI.mp4
#    ✅ Success! Saved to: cljwbentj000d3n6lkdzqc77e.mp4
#
# [150/1383] Extracting: cljwbftxx000h3n6lv1v7w0ux
#    Video: eOe2AgVK5xI (abnormal)
#    Frames: 1232-1468 (237 frames)
#    Source: eOe2AgVK5xI.mp4
#    ✅ Success! Saved to: cljwbftxx000h3n6lv1v7w0ux.mp4
#
# [151/1383] Extracting: cljwbgqhk000l3n6lyl2bs2we
#    Video: eOe2AgVK5xI (abnormal)
#    Frames: 1885-2058 (174 frames)
#    Source: eOe2AgVK5xI.mp4
#    ✅ Success! Saved to: cljwbgqhk000l3n6lyl2bs2we.mp4
#
# [152/1383] Extracting: cljwbhsda000p3n6lo07fktzr
#    Video: eOe2AgVK5xI (abnormal)
#    Frames: 2364-2495 (132 frames)
#    Source: eOe2AgVK5xI.mp4
#    ✅ Success! Saved to: cljwbhsda000p3n6lo07fktzr.mp4
#
# [153/1383] Extracting: cljwbiep2000t3n6l0xm73f73
#    Video: eOe2AgVK5xI (abnormal)
#    Frames: 2632-2718 (87 frames)
#    Source: eOe2AgVK5xI.mp4
#    ✅ Success! Saved to: cljwbiep2000t3n6l0xm73f73.mp4
#
# [154/1383] Extracting: cljwbiw4g000x3n6lzn7gplp8
#    Video: eOe2AgVK5xI (abnormal)
#    Frames: 2728-2936 (209 frames)
#    Source: eOe2AgVK5xI.mp4
#    ✅ Success! Saved to: cljwbiw4g000x3n6lzn7gplp8.mp4
#
# [155/1383] Extracting: cljwbkl5u00113n6lq6juqm6c
#    Video: eOe2AgVK5xI (abnormal)
#    Frames: 3317-3476 (160 frames)
#    Source: eOe2AgVK5xI.mp4
#    ✅ Success! Saved to: cljwbkl5u00113n6lq6juqm6c.mp4
#
# [156/1383] Extracting: cljwbmxjq00163n6lbdlems0m
#    Video: es5nSkAx4p4 (abnormal)
#    Frames: 550-903 (354 frames)
#    Source: es5nSkAx4p4.mp4
#    ✅ Success! Saved to: cljwbmxjq00163n6lbdlems0m.mp4
#
# [157/1383] Extracting: cljwbp6ll001b3n6lcbxh7liq
#    Video: Exqj0M000S8 (stroke)
#    Frames: 121-155 (35 frames)
#    Source: Exqj0M000S8.mp4
#    ✅ Success! Saved to: cljwbp6ll001b3n6lcbxh7liq.mp4
#
# [158/1383] Extracting: cljwbqprx001f3n6l49fulwhf
#    Video: Exqj0M000S8 (stroke)
#    Frames: 7040-7194 (155 frames)
#    Source: Exqj0M000S8.mp4
#    ✅ Success! Saved to: cljwbqprx001f3n6l49fulwhf.mp4
#
# [159/1383] Extracting: cljwbrss4001k3n6l6oaj5ayy
#    Video: f1Jt0xVqvtI (exercise)
#    Frames: 322-584 (263 frames)
#    Source: f1Jt0xVqvtI.mp4
#    ✅ Success! Saved to: cljwbrss4001k3n6l6oaj5ayy.mp4
#
# [160/1383] Extracting: cljwbsax5001o3n6lgoj7f57r
#    Video: f1Jt0xVqvtI (exercise)
#    Frames: 593-869 (277 frames)
#    Source: f1Jt0xVqvtI.mp4
#    ✅ Success! Saved to: cljwbsax5001o3n6lgoj7f57r.mp4
#
# [161/1383] Extracting: cljwbtjtg001t3n6lg3w779jv
#    Video: f8h2nkV0R8A (cerebral palsy)
#    Frames: 2779-2972 (194 frames)
#    Source: f8h2nkV0R8A.mp4
#    ✅ Success! Saved to: cljwbtjtg001t3n6lg3w779jv.mp4
#
# [162/1383] Extracting: cljwcn068001y3n6lrm6qqj8o
#    Video: FElCDD3X8pI (myopathic)
#    Frames: 1-887 (887 frames)
#    Source: FElCDD3X8pI.mp4
#    ✅ Success! Saved to: cljwcn068001y3n6lrm6qqj8o.mp4
#
# [163/1383] Extracting: cljwcp4ds00233n6lr9hvtf73
#    Video: FoWTST-lrZw (exercise)
#    Frames: 388-686 (299 frames)
#    Source: FoWTST-lrZw.mp4
#    ✅ Success! Saved to: cljwcp4ds00233n6lr9hvtf73.mp4
#
# [164/1383] Extracting: cljwcqyw500283n6lcmqv13n0
#    Video: FpXbeLZWFSw (stroke)
#    Frames: 1982-3345 (1364 frames)
#    Source: FpXbeLZWFSw.mp4
#    ✅ Success! Saved to: cljwcqyw500283n6lcmqv13n0.mp4
#
# [165/1383] Extracting: cljwcrswx002c3n6lwn7iv6br
#    Video: FpXbeLZWFSw (stroke)
#    Frames: 3477-4877 (1401 frames)
#    Source: FpXbeLZWFSw.mp4
#    ✅ Success! Saved to: cljwcrswx002c3n6lwn7iv6br.mp4
#
# [166/1383] Extracting: cljwcsw38002g3n6l088m4lb7
#    Video: FpXbeLZWFSw (stroke)
#    Frames: 4986-6400 (1415 frames)
#    Source: FpXbeLZWFSw.mp4
#    ✅ Success! Saved to: cljwcsw38002g3n6l088m4lb7.mp4
#
# [167/1383] Extracting: cljwctrwx002k3n6lv7z0eodd
#    Video: FpXbeLZWFSw (stroke)
#    Frames: 6535-7993 (1459 frames)
#    Source: FpXbeLZWFSw.mp4
#    ✅ Success! Saved to: cljwctrwx002k3n6lv7z0eodd.mp4
#
# [168/1383] Extracting: cljwcu98s002o3n6lgvojbey3
#    Video: FpXbeLZWFSw (stroke)
#    Frames: 8113-9580 (1468 frames)
#    Source: FpXbeLZWFSw.mp4
#    ✅ Success! Saved to: cljwcu98s002o3n6lgvojbey3.mp4
#
# [169/1383] Extracting: cljwcurcc002s3n6lvrwlkbni
#    Video: FpXbeLZWFSw (stroke)
#    Frames: 9702-11179 (1478 frames)
#    Source: FpXbeLZWFSw.mp4
#    ✅ Success! Saved to: cljwcurcc002s3n6lvrwlkbni.mp4
#
# [170/1383] Extracting: cljwcvfg5002w3n6lo9eg0k8w
#    Video: FpXbeLZWFSw (stroke)
#    Frames: 11290-12808 (1519 frames)
#    Source: FpXbeLZWFSw.mp4
#    ✅ Success! Saved to: cljwcvfg5002w3n6lo9eg0k8w.mp4
#
# [171/1383] Extracting: cljwcx6nj00043n6l90obz35w
#    Video: F-T39hlQ6i0 (exercise)
#    Frames: 71-233 (163 frames)
#    Source: F-T39hlQ6i0.mp4
#    ✅ Success! Saved to: cljwcx6nj00043n6l90obz35w.mp4
#
# [172/1383] Extracting: cljwcxjlo00083n6lkqia9zx0
#    Video: F-T39hlQ6i0 (exercise)
#    Frames: 313-489 (177 frames)
#    Source: F-T39hlQ6i0.mp4
#    ✅ Success! Saved to: cljwcxjlo00083n6lkqia9zx0.mp4
#
# [173/1383] Extracting: cljwcz4en000d3n6lf1g0j311
#    Video: fTfkU1gJLO4 (abnormal)
#    Frames: 1-118 (118 frames)
#    Source: fTfkU1gJLO4.mp4
#    ✅ Success! Saved to: cljwcz4en000d3n6lf1g0j311.mp4
#
# [174/1383] Extracting: cljwczhuy000h3n6l84ebe3ao
#    Video: fTfkU1gJLO4 (abnormal)
#    Frames: 189-436 (248 frames)
#    Source: fTfkU1gJLO4.mp4
#    ✅ Success! Saved to: cljwczhuy000h3n6l84ebe3ao.mp4
#
# [175/1383] Extracting: cljwd0g2x000m3n6lgzb8jcwo
#    Video: FtpcgPPcySk (abnormal)
#    Frames: 1-100 (100 frames)
#    Source: FtpcgPPcySk.mp4
#    ✅ Success! Saved to: cljwd0g2x000m3n6lgzb8jcwo.mp4
#
# [176/1383] Extracting: cljwd0zll000q3n6lg38q5kzy
#    Video: FtpcgPPcySk (abnormal)
#    Frames: 125-247 (123 frames)
#    Source: FtpcgPPcySk.mp4
#    ✅ Success! Saved to: cljwd0zll000q3n6lg38q5kzy.mp4
#
# [177/1383] Extracting: cljwd1n5o000u3n6lo2vje4yj
#    Video: FtpcgPPcySk (abnormal)
#    Frames: 991-1258 (268 frames)
#    Source: FtpcgPPcySk.mp4
#    ✅ Success! Saved to: cljwd1n5o000u3n6lo2vje4yj.mp4
#
# [178/1383] Extracting: cljwd2k4l000y3n6lp5jngk5e
#    Video: FtpcgPPcySk (abnormal)
#    Frames: 1369-1541 (173 frames)
#    Source: FtpcgPPcySk.mp4
#    ✅ Success! Saved to: cljwd2k4l000y3n6lp5jngk5e.mp4
#
# [179/1383] Extracting: cljwd3oac00123n6llcxe2tg1
#    Video: G0RIf53oyBw (antalgic)
#    Frames: 205-310 (106 frames)
#    Source: G0RIf53oyBw.mp4
#    ✅ Success! Saved to: cljwd3oac00123n6llcxe2tg1.mp4
#
# [180/1383] Extracting: cljwd49i700163n6lxv579o8a
#    Video: G0RIf53oyBw (antalgic)
#    Frames: 359-497 (139 frames)
#    Source: G0RIf53oyBw.mp4
#    ✅ Success! Saved to: cljwd49i700163n6lxv579o8a.mp4
#
# [181/1383] Extracting: cljwd53nu001a3n6l8lu2lz3u
#    Video: G0RIf53oyBw (antalgic)
#    Frames: 588-695 (108 frames)
#    Source: G0RIf53oyBw.mp4
#    ✅ Success! Saved to: cljwd53nu001a3n6l8lu2lz3u.mp4
#
# [182/1383] Extracting: cljwd5h2s001e3n6l14zums1l
#    Video: G0RIf53oyBw (antalgic)
#    Frames: 732-875 (144 frames)
#    Source: G0RIf53oyBw.mp4
#    ✅ Success! Saved to: cljwd5h2s001e3n6l14zums1l.mp4
#
# [183/1383] Extracting: cljwd6kxa001i3n6lm1mk8bg8
#    Video: gBvMHns6N90 (abnormal)
#    Frames: 58-241 (184 frames)
#    Source: gBvMHns6N90.mp4
#    ✅ Success! Saved to: cljwd6kxa001i3n6lm1mk8bg8.mp4
#
# [184/1383] Extracting: cljwd7gqa001m3n6lteailldg
#    Video: gBvMHns6N90 (abnormal)
#    Frames: 266-437 (172 frames)
#    Source: gBvMHns6N90.mp4
#    ✅ Success! Saved to: cljwd7gqa001m3n6lteailldg.mp4
#
# [185/1383] Extracting: cljwd7wey001q3n6lgwlba49x
#    Video: gBvMHns6N90 (abnormal)
#    Frames: 449-572 (124 frames)
#    Source: gBvMHns6N90.mp4
#    ✅ Success! Saved to: cljwd7wey001q3n6lgwlba49x.mp4
#
# [186/1383] Extracting: cljwd8jby001u3n6lizluv10f
#    Video: gBvMHns6N90 (abnormal)
#    Frames: 599-836 (238 frames)
#    Source: gBvMHns6N90.mp4
#    ✅ Success! Saved to: cljwd8jby001u3n6lizluv10f.mp4
#
# [187/1383] Extracting: cljwd92y7001y3n6lz7l3kpb7
#    Video: gBvMHns6N90 (abnormal)
#    Frames: 840-1015 (176 frames)
#    Source: gBvMHns6N90.mp4
#    ✅ Success! Saved to: cljwd92y7001y3n6lz7l3kpb7.mp4
#
# [188/1383] Extracting: clk6kbxrx000c3n6lnxcdhw1x
#    Video: dGSMgtCmk-A (exercise)
#    Frames: 3627-3821 (195 frames)
#    Source: dGSMgtCmk-A.mp4
#    ✅ Success! Saved to: clk6kbxrx000c3n6lnxcdhw1x.mp4
#
# [189/1383] Extracting: clk6kdbvm000g3n6ln30mqzw6
#    Video: dGSMgtCmk-A (exercise)
#    Frames: 6522-6784 (263 frames)
#    Source: dGSMgtCmk-A.mp4
#    ✅ Success! Saved to: clk6kdbvm000g3n6ln30mqzw6.mp4
#
# [190/1383] Extracting: clk6km1dx000p3n6lg1prr2xr
#    Video: e5lPjg0GhFM (exercise)
#    Frames: 1-323 (323 frames)
#    Source: e5lPjg0GhFM.mp4
#    ✅ Success! Saved to: clk6km1dx000p3n6lg1prr2xr.mp4
#
# [191/1383] Extracting: clk6ko1kf000w3n6l3wq5uxbi
#    Video: edYFuhaff7c (exercise)
#    Frames: 1-300 (300 frames)
#    Source: edYFuhaff7c.mp4
#    ✅ Success! Saved to: clk6ko1kf000w3n6l3wq5uxbi.mp4
#
# [192/1383] Extracting: clk6kqt7000163n6liyzaaif6
#    Video: ErkLnvUHQuc (abnormal)
#    Frames: 1-198 (198 frames)
#    Source: ErkLnvUHQuc.mp4
#    ✅ Success! Saved to: clk6kqt7000163n6liyzaaif6.mp4
#
# [193/1383] Extracting: clk6krh1l001a3n6le4octg6x
#    Video: ErkLnvUHQuc (abnormal)
#    Frames: 1124-1761 (638 frames)
#    Source: ErkLnvUHQuc.mp4
#    ✅ Success! Saved to: clk6krh1l001a3n6le4octg6x.mp4
#
# [194/1383] Extracting: clk6ks8hy001e3n6labhtzxzt
#    Video: ErkLnvUHQuc (abnormal)
#    Frames: 1783-1958 (176 frames)
#    Source: ErkLnvUHQuc.mp4
#    ✅ Success! Saved to: clk6ks8hy001e3n6labhtzxzt.mp4
#
# [195/1383] Extracting: clk6ksjhi001i3n6la1jkwelz
#    Video: ErkLnvUHQuc (abnormal)
#    Frames: 2004-2189 (186 frames)
#    Source: ErkLnvUHQuc.mp4
#    ✅ Success! Saved to: clk6ksjhi001i3n6la1jkwelz.mp4
#
# [196/1383] Extracting: clk6ksvq7001l3n6lh5doclng
#    Video: ErkLnvUHQuc (abnormal)
#    Frames: 2212-2696 (485 frames)
#    Source: ErkLnvUHQuc.mp4
#    ✅ Success! Saved to: clk6ksvq7001l3n6lh5doclng.mp4
#
# [197/1383] Extracting: clk6ktoi4001o3n6l2m6oag7i
#    Video: ErkLnvUHQuc (abnormal)
#    Frames: 2831-3475 (645 frames)
#    Source: ErkLnvUHQuc.mp4
#    ✅ Success! Saved to: clk6ktoi4001o3n6l2m6oag7i.mp4
#
# [198/1383] Extracting: clk6kx8jj001u3n6lwnfad24d
#    Video: es5nSkAx4p4 (abnormal)
#    Frames: 1731-1863 (133 frames)
#    Source: es5nSkAx4p4.mp4
#    ✅ Success! Saved to: clk6kx8jj001u3n6lwnfad24d.mp4
#
# [199/1383] Extracting: clk6ky7b5001z3n6l2xsvs2z2
#    Video: esn4r6L-rhQ (exercise)
#    Frames: 948-1152 (205 frames)
#    Source: esn4r6L-rhQ.mp4
#    ✅ Success! Saved to: clk6ky7b5001z3n6l2xsvs2z2.mp4
#
# [200/1383] Extracting: clk6kym3f00233n6lkpm2dxnq
#    Video: esn4r6L-rhQ (exercise)
#    Frames: 1225-1712 (488 frames)
#    Source: esn4r6L-rhQ.mp4
#    ✅ Success! Saved to: clk6kym3f00233n6lkpm2dxnq.mp4
#
# [201/1383] Extracting: clk6l0fy800293n6lhh1t24pc
#    Video: ETQKvb8Ulqs (exercise)
#    Frames: 1124-1340 (217 frames)
#    Source: ETQKvb8Ulqs.mp4
#    ✅ Success! Saved to: clk6l0fy800293n6lhh1t24pc.mp4
#
# [202/1383] Extracting: clk6l0vqc002d3n6lfp1rdygf
#    Video: ETQKvb8Ulqs (exercise)
#    Frames: 1363-1884 (522 frames)
#    Source: ETQKvb8Ulqs.mp4
#    ✅ Success! Saved to: clk6l0vqc002d3n6lfp1rdygf.mp4
#
# [203/1383] Extracting: clk6l1mlq002h3n6lvt6phaxh
#    Video: ETQKvb8Ulqs (exercise)
#    Frames: 1903-2052 (150 frames)
#    Source: ETQKvb8Ulqs.mp4
#    ✅ Success! Saved to: clk6l1mlq002h3n6lvt6phaxh.mp4
#
# [204/1383] Extracting: clk6l28gd002l3n6l0sh6iyud
#    Video: ETQKvb8Ulqs (exercise)
#    Frames: 2070-2455 (386 frames)
#    Source: ETQKvb8Ulqs.mp4
#    ✅ Success! Saved to: clk6l28gd002l3n6l0sh6iyud.mp4
#
# [205/1383] Extracting: clk6l5hsj002w3n6lrta6djle
#    Video: Exqj0M000S8 (stroke)
#    Frames: 3747-3890 (144 frames)
#    Source: Exqj0M000S8.mp4
#    ✅ Success! Saved to: clk6l5hsj002w3n6lrta6djle.mp4
#
# [206/1383] Extracting: clk6l6t7v00313n6ljaiz1cl6
#    Video: eWY8_dzinJk (exercise)
#    Frames: 471-870 (400 frames)
#    Source: eWY8_dzinJk.mp4
#    ✅ Success! Saved to: clk6l6t7v00313n6ljaiz1cl6.mp4
#
# [207/1383] Extracting: clk6l7f4h00353n6ldqj6x8z2
#    Video: eWY8_dzinJk (exercise)
#    Frames: 936-1363 (428 frames)
#    Source: eWY8_dzinJk.mp4
#    ✅ Success! Saved to: clk6l7f4h00353n6ldqj6x8z2.mp4
#
# [208/1383] Extracting: clk6lapp7003e3n6lnpqtai54
#    Video: fbY4O04uunE (stroke)
#    Frames: 1-433 (433 frames)
#    Source: fbY4O04uunE.mp4
#    ✅ Success! Saved to: clk6lapp7003e3n6lnpqtai54.mp4
#
# [209/1383] Extracting: clk6lb2my003i3n6lesxxkgpf
#    Video: fbY4O04uunE (stroke)
#    Frames: 487-1033 (547 frames)
#    Source: fbY4O04uunE.mp4
#    ✅ Success! Saved to: clk6lb2my003i3n6lesxxkgpf.mp4
#
# [210/1383] Extracting: clk6lbly5003m3n6l9bjdqiyz
#    Video: fbY4O04uunE (stroke)
#    Frames: 1053-2177 (1125 frames)
#    Source: fbY4O04uunE.mp4
#    ✅ Success! Saved to: clk6lbly5003m3n6l9bjdqiyz.mp4
#
# [211/1383] Extracting: clk6lc90h003q3n6lppkjh9f0
#    Video: fbY4O04uunE (stroke)
#    Frames: 2201-3454 (1254 frames)
#    Source: fbY4O04uunE.mp4
#    ✅ Success! Saved to: clk6lc90h003q3n6lppkjh9f0.mp4
#
# [212/1383] Extracting: clk6lcq54003u3n6llqcmuee5
#    Video: fbY4O04uunE (stroke)
#    Frames: 3468-4247 (780 frames)
#    Source: fbY4O04uunE.mp4
#    ✅ Success! Saved to: clk6lcq54003u3n6llqcmuee5.mp4
#
# [213/1383] Extracting: clk6ld20x003y3n6lmooncyx3
#    Video: fbY4O04uunE (stroke)
#    Frames: 4291-4715 (425 frames)
#    Source: fbY4O04uunE.mp4
#    ✅ Success! Saved to: clk6ld20x003y3n6lmooncyx3.mp4
#
# [214/1383] Extracting: clk6ldflp00423n6l9q27b78p
#    Video: fbY4O04uunE (stroke)
#    Frames: 4742-6120 (1379 frames)
#    Source: fbY4O04uunE.mp4
#    ✅ Success! Saved to: clk6ldflp00423n6l9q27b78p.mp4
#
# [215/1383] Extracting: clk6le8lt00463n6l6op89c4x
#    Video: fbY4O04uunE (stroke)
#    Frames: 6180-7755 (1576 frames)
#    Source: fbY4O04uunE.mp4
#    ✅ Success! Saved to: clk6le8lt00463n6l6op89c4x.mp4
#
# [216/1383] Extracting: clk6lhj5y004l3n6l6hlpkdfp
#    Video: fGY7PMK3cVU (exercise)
#    Frames: 327-698 (372 frames)
#    Source: fGY7PMK3cVU.mp4
#    ✅ Success! Saved to: clk6lhj5y004l3n6l6hlpkdfp.mp4
#
# [217/1383] Extracting: clk6li116004p3n6lxwvkwmoh
#    Video: fGY7PMK3cVU (exercise)
#    Frames: 711-1122 (412 frames)
#    Source: fGY7PMK3cVU.mp4
#    ✅ Success! Saved to: clk6li116004p3n6lxwvkwmoh.mp4
#
# [218/1383] Extracting: clk6lmg90004w3n6l0o506aay
#    Video: fGY7PMK3cVU (exercise)
#    Frames: 1462-1611 (150 frames)
#    Source: fGY7PMK3cVU.mp4
#    ✅ Success! Saved to: clk6lmg90004w3n6l0o506aay.mp4
#
# [219/1383] Extracting: clk6lmzcw00503n6l851ywdpd
#    Video: fGY7PMK3cVU (exercise)
#    Frames: 1624-1951 (328 frames)
#    Source: fGY7PMK3cVU.mp4
#    ✅ Success! Saved to: clk6lmzcw00503n6l851ywdpd.mp4
#
# [220/1383] Extracting: clk6lnf1400543n6l9daxq3je
#    Video: fGY7PMK3cVU (exercise)
#    Frames: 1965-2272 (308 frames)
#    Source: fGY7PMK3cVU.mp4
#    ✅ Success! Saved to: clk6lnf1400543n6l9daxq3je.mp4
#
# [221/1383] Extracting: cll1tbuth00053o6lx6ohlub5
#    Video: b0KrA_96Ks0 (parkinsons)
#    Frames: 146-561 (416 frames)
#    Source: b0KrA_96Ks0.mp4
#    ✅ Success! Saved to: cll1tbuth00053o6lx6ohlub5.mp4
#
# [222/1383] Extracting: cll1tcctq00093o6l30ew8fz2
#    Video: b0KrA_96Ks0 (parkinsons)
#    Frames: 647-983 (337 frames)
#    Source: b0KrA_96Ks0.mp4
#    ✅ Success! Saved to: cll1tcctq00093o6l30ew8fz2.mp4
#
# [223/1383] Extracting: cll1tfz0t000e3o6l6ypxvap2
#    Video: FwJlEV6M1hk (abnormal)
#    Frames: 1-262 (262 frames)
#    Source: FwJlEV6M1hk.mp4
#    ✅ Success! Saved to: cll1tfz0t000e3o6l6ypxvap2.mp4
#
# [224/1383] Extracting: cll1tggon000i3o6lpdnpztyg
#    Video: FwJlEV6M1hk (abnormal)
#    Frames: 301-553 (253 frames)
#    Source: FwJlEV6M1hk.mp4
#    ✅ Success! Saved to: cll1tggon000i3o6lpdnpztyg.mp4
#
# [225/1383] Extracting: cll1tgy4z000m3o6lon7dsr95
#    Video: FwJlEV6M1hk (abnormal)
#    Frames: 582-1336 (755 frames)
#    Source: FwJlEV6M1hk.mp4
#    ✅ Success! Saved to: cll1tgy4z000m3o6lon7dsr95.mp4
#
# [226/1383] Extracting: cll1thi3n000q3o6lnr0j6u0f
#    Video: FwJlEV6M1hk (abnormal)
#    Frames: 1506-2349 (844 frames)
#    Source: FwJlEV6M1hk.mp4
#    ✅ Success! Saved to: cll1thi3n000q3o6lnr0j6u0f.mp4
#
# [227/1383] Extracting: cll1tjali000v3o6lz1q0sbhh
#    Video: G5iGtnC06YU (abnormal)
#    Frames: 337-435 (99 frames)
#    Source: G5iGtnC06YU.mp4
#    ✅ Success! Saved to: cll1tjali000v3o6lz1q0sbhh.mp4
#
# [228/1383] Extracting: cll1tjqey000z3o6l9rxk74ly
#    Video: G5iGtnC06YU (abnormal)
#    Frames: 447-590 (144 frames)
#    Source: G5iGtnC06YU.mp4
#    ✅ Success! Saved to: cll1tjqey000z3o6l9rxk74ly.mp4
#
# [229/1383] Extracting: cll1tkcu900133o6lebvnmt2x
#    Video: G5iGtnC06YU (abnormal)
#    Frames: 682-734 (53 frames)
#    Source: G5iGtnC06YU.mp4
#    ✅ Success! Saved to: cll1tkcu900133o6lebvnmt2x.mp4
#
# [230/1383] Extracting: cll1tl72s00183o6lidwjpm4l
#    Video: G6QVztrW93k (exercise)
#    Frames: 147-269 (123 frames)
#    Source: G6QVztrW93k.mp4
#    ✅ Success! Saved to: cll1tl72s00183o6lidwjpm4l.mp4
#
# [231/1383] Extracting: cll1tlpxj001c3o6lkqkvvqhq
#    Video: G6QVztrW93k (exercise)
#    Frames: 330-460 (131 frames)
#    Source: G6QVztrW93k.mp4
#    ✅ Success! Saved to: cll1tlpxj001c3o6lkqkvvqhq.mp4
#
# [232/1383] Extracting: cll1tmroq001h3o6loxlzrj86
#    Video: gBvMHns6N90 (abnormal)
#    Frames: 1024-1211 (188 frames)
#    Source: gBvMHns6N90.mp4
#    ✅ Success! Saved to: cll1tmroq001h3o6loxlzrj86.mp4
#
# [233/1383] Extracting: cll1tnnrs001n3o6lkc9v4mgo
#    Video: gEQ9je2hiGE (abnormal)
#    Frames: 1-182 (182 frames)
#    Source: gEQ9je2hiGE.mp4
#    ✅ Success! Saved to: cll1tnnrs001n3o6lkc9v4mgo.mp4
#
# [234/1383] Extracting: cll1tpvdm001v3o6lpqzlnorv
#    Video: GJCHyOxnPIU (abnormal)
#    Frames: 117-292 (176 frames)
#    Source: GJCHyOxnPIU.mp4
#    ✅ Success! Saved to: cll1tpvdm001v3o6lpqzlnorv.mp4
#
# [235/1383] Extracting: cll1tqcty001z3o6lieri2lsg
#    Video: GJCHyOxnPIU (abnormal)
#    Frames: 522-815 (294 frames)
#    Source: GJCHyOxnPIU.mp4
#    ✅ Success! Saved to: cll1tqcty001z3o6lieri2lsg.mp4
#
# [236/1383] Extracting: cll1tqrrx00233o6lomml91s1
#    Video: GJCHyOxnPIU (abnormal)
#    Frames: 923-1266 (344 frames)
#    Source: GJCHyOxnPIU.mp4
#    ✅ Success! Saved to: cll1tqrrx00233o6lomml91s1.mp4
#
# [237/1383] Extracting: cll1tsq1n00293o6lu7c9kurh
#    Video: gOMr8ezwiSU (exercise)
#    Frames: 1013-1209 (197 frames)
#    Source: gOMr8ezwiSU.mp4
#    ✅ Success! Saved to: cll1tsq1n00293o6lu7c9kurh.mp4
#
# [238/1383] Extracting: cll1tta09002d3o6l4kroorkw
#    Video: gOMr8ezwiSU (exercise)
#    Frames: 1573-1753 (181 frames)
#    Source: gOMr8ezwiSU.mp4
#    ✅ Success! Saved to: cll1tta09002d3o6l4kroorkw.mp4
# ❌ [240/1383] cll1tu9x4002j3o6linf569oq: Video file not found
#
# [240/1383] Extracting: cll1tvded002o3o6lqnb31xmm
#    Video: gRSNMxt9ZmM (abnormal)
#    Frames: 672-1018 (347 frames)
#    Source: gRSNMxt9ZmM.mp4
#    ✅ Success! Saved to: cll1tvded002o3o6lqnb31xmm.mp4
#
# [241/1383] Extracting: cll445m9200063o6lo2sbn0n7
#    Video: H7WThdv-fCQ (pregnant)
#    Frames: 55-222 (168 frames)
#    Source: H7WThdv-fCQ.mp4
#    ✅ Success! Saved to: cll445m9200063o6lo2sbn0n7.mp4
#
# [242/1383] Extracting: cll446i2s000c3o6lffxji1s2
#    Video: H7WThdv-fCQ (pregnant)
#    Frames: 271-449 (179 frames)
#    Source: H7WThdv-fCQ.mp4
#    ✅ Success! Saved to: cll446i2s000c3o6lffxji1s2.mp4
#
# [243/1383] Extracting: cll44833z000j3o6lwxof7566
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 1-270 (270 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll44833z000j3o6lwxof7566.mp4
#
# [244/1383] Extracting: cll4494ux000n3o6lyqr7dx4l
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 293-459 (167 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll4494ux000n3o6lyqr7dx4l.mp4
#
# [245/1383] Extracting: cll449lal000t3o6lv4pja4l7
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 469-653 (185 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll449lal000t3o6lv4pja4l7.mp4
#
# [246/1383] Extracting: cll44a69n000z3o6l8p6gooxx
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 665-939 (275 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll44a69n000z3o6l8p6gooxx.mp4
#
# [247/1383] Extracting: cll44ar0q00153o6luv35dhl0
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 958-1109 (152 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll44ar0q00153o6luv35dhl0.mp4
#
# [248/1383] Extracting: cll44balt00193o6lbzpyxlqq
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 1135-1495 (361 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll44balt00193o6lbzpyxlqq.mp4
#
# [249/1383] Extracting: cll44bzhg001f3o6l7spc508t
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 1873-1995 (123 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll44bzhg001f3o6l7spc508t.mp4
#
# [250/1383] Extracting: cll44cgt0001l3o6lsn9qb73s
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 2014-2142 (129 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll44cgt0001l3o6lsn9qb73s.mp4
#
# [251/1383] Extracting: cll44cxvz001r3o6l42os54zz
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 2185-2397 (213 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll44cxvz001r3o6l42os54zz.mp4
#
# [252/1383] Extracting: cll44dip4001x3o6l2pa7optw
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 2415-2541 (127 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll44dip4001x3o6l2pa7optw.mp4
#
# [253/1383] Extracting: cll44e48l00233o6lu0msccp4
#    Video: Ha9LKXZfWBQ (myopathic)
#    Frames: 2614-2733 (120 frames)
#    Source: Ha9LKXZfWBQ.mp4
#    ✅ Success! Saved to: cll44e48l00233o6lu0msccp4.mp4
#
# [254/1383] Extracting: cll44faz0002b3o6lkfu2oggx
#    Video: HEoUhlesN9E (abnormal)
#    Frames: 73-161 (89 frames)
#    Source: HEoUhlesN9E.mp4
#    ✅ Success! Saved to: cll44faz0002b3o6lkfu2oggx.mp4
#
# [255/1383] Extracting: cll44hiwd002e3o6llv2e9o9t
#    Video: HEoUhlesN9E (abnormal)
#    Frames: 163-252 (90 frames)
#    Source: HEoUhlesN9E.mp4
#    ✅ Success! Saved to: cll44hiwd002e3o6llv2e9o9t.mp4
#
# [256/1383] Extracting: cll44hwjc002i3o6lqv6hv0ze
#    Video: HEoUhlesN9E (abnormal)
#    Frames: 253-342 (90 frames)
#    Source: HEoUhlesN9E.mp4
#    ✅ Success! Saved to: cll44hwjc002i3o6lqv6hv0ze.mp4
#
# [257/1383] Extracting: cll44i8u8002l3o6l70vg7c0k
#    Video: HEoUhlesN9E (abnormal)
#    Frames: 343-432 (90 frames)
#    Source: HEoUhlesN9E.mp4
#    ✅ Success! Saved to: cll44i8u8002l3o6l70vg7c0k.mp4
#
# [258/1383] Extracting: cll44iuad002o3o6l836m07p6
#    Video: HEoUhlesN9E (abnormal)
#    Frames: 433-522 (90 frames)
#    Source: HEoUhlesN9E.mp4
#    ✅ Success! Saved to: cll44iuad002o3o6l836m07p6.mp4
#
# [259/1383] Extracting: cll44jfs6002s3o6lx81eaw9d
#    Video: HEoUhlesN9E (abnormal)
#    Frames: 523-612 (90 frames)
#    Source: HEoUhlesN9E.mp4
#    ✅ Success! Saved to: cll44jfs6002s3o6lx81eaw9d.mp4
#
# [260/1383] Extracting: cll44jukm002v3o6lri55zuf7
#    Video: HEoUhlesN9E (abnormal)
#    Frames: 613-702 (90 frames)
#    Source: HEoUhlesN9E.mp4
#    ✅ Success! Saved to: cll44jukm002v3o6lri55zuf7.mp4
#
# [261/1383] Extracting: cll44k63a002y3o6l5mrc1stg
#    Video: HEoUhlesN9E (abnormal)
#    Frames: 703-793 (91 frames)
#    Source: HEoUhlesN9E.mp4
#    ✅ Success! Saved to: cll44k63a002y3o6l5mrc1stg.mp4
#
# [262/1383] Extracting: cll44kk8300323o6l8rw8x8gy
#    Video: HEoUhlesN9E (abnormal)
#    Frames: 794-882 (89 frames)
#    Source: HEoUhlesN9E.mp4
# ...
#    ✅ Success! Saved to: cllamrqq8003v3o6lk9rfdt01.mp4
#
# [1306/1383] Extracting: cllamsonz003z3o6lwrp5vstm
#    Video: Z4vLObF-0Yo (inebriated)
#    Frames: 668-772 (105 frames)
#    Source: Z4vLObF-0Yo.mp4
#    ✅ Success! Saved to: cllamsonz003z3o6lwrp5vstm.mp4
#
# [1307/1383] Extracting: cllamwa5z00493o6lnpn080ov
#    Video: zJ6PFxJrGf8 (myopathic)
#    Frames: 3567-3793 (227 frames)
#    Source: zJ6PFxJrGf8.mp4
#    ✅ Success! Saved to: cllamwa5z00493o6lnpn080ov.mp4
#
# [1308/1383] Extracting: cllamwozn004d3o6l7puz81dt
#    Video: zJ6PFxJrGf8 (myopathic)
#    Frames: 3831-4095 (265 frames)
#    Source: zJ6PFxJrGf8.mp4
#    ✅ Success! Saved to: cllamwozn004d3o6l7puz81dt.mp4
#
# [1309/1383] Extracting: cllamxx59004k3o6lkg8cvmpl
#    Video: zJ6PFxJrGf8 (myopathic)
#    Frames: 4396-4819 (424 frames)
#    Source: zJ6PFxJrGf8.mp4
#    ✅ Success! Saved to: cllamxx59004k3o6lkg8cvmpl.mp4
#
# [1310/1383] Extracting: cllamyil1004o3o6lsl7ye5jj
#    Video: zJ6PFxJrGf8 (myopathic)
#    Frames: 4863-5051 (189 frames)
#    Source: zJ6PFxJrGf8.mp4
#    ✅ Success! Saved to: cllamyil1004o3o6lsl7ye5jj.mp4
# ❌ [1312/1383] cllanmdaj004t3o6l87rnq2m9: Video file not found
#
# [1312/1383] Extracting: cllano2w1004y3o6la5r54560
#    Video: ZmpGIPxKlok (abnormal)
#    Frames: 502-1149 (648 frames)
#    Source: ZmpGIPxKlok.mp4
#    ✅ Success! Saved to: cllano2w1004y3o6la5r54560.mp4
#
# [1313/1383] Extracting: cllanpawc00523o6lue6quxgr
#    Video: ZmpGIPxKlok (abnormal)
#    Frames: 4284-4384 (101 frames)
#    Source: ZmpGIPxKlok.mp4
#    ✅ Success! Saved to: cllanpawc00523o6lue6quxgr.mp4
#
# [1314/1383] Extracting: cllanpv2600563o6lzc4igc2r
#    Video: ZmpGIPxKlok (abnormal)
#    Frames: 4461-4550 (90 frames)
#    Source: ZmpGIPxKlok.mp4
#    ✅ Success! Saved to: cllanpv2600563o6lzc4igc2r.mp4
#
# [1315/1383] Extracting: cllba0y1700053o6ls6ms2md9
#    Video: XWaVMuR_o8w (exercise)
#    Frames: 635-744 (110 frames)
#    Source: XWaVMuR_o8w.mp4
#    ✅ Success! Saved to: cllba0y1700053o6ls6ms2md9.mp4
#
# [1316/1383] Extracting: cllba1khy00093o6l3l358uz7
#    Video: XWaVMuR_o8w (exercise)
#    Frames: 871-1008 (138 frames)
#    Source: XWaVMuR_o8w.mp4
#    ✅ Success! Saved to: cllba1khy00093o6l3l358uz7.mp4
#
# [1317/1383] Extracting: cllba1zj9000d3o6lsgqt9rxz
#    Video: XWaVMuR_o8w (exercise)
#    Frames: 1252-1334 (83 frames)
#    Source: XWaVMuR_o8w.mp4
#    ✅ Success! Saved to: cllba1zj9000d3o6lsgqt9rxz.mp4
#
# [1318/1383] Extracting: cllba2d6w000g3o6lx6kwyah0
#    Video: XWaVMuR_o8w (exercise)
#    Frames: 1336-1427 (92 frames)
#    Source: XWaVMuR_o8w.mp4
#    ✅ Success! Saved to: cllba2d6w000g3o6lx6kwyah0.mp4
#
# [1319/1383] Extracting: cllba340u000k3o6lfxhoh96p
#    Video: XWaVMuR_o8w (exercise)
#    Frames: 2071-2266 (196 frames)
#    Source: XWaVMuR_o8w.mp4
#    ✅ Success! Saved to: cllba340u000k3o6lfxhoh96p.mp4
#
# [1320/1383] Extracting: cllba3xz8000p3o6lpaedkp88
#    Video: w2fYQyikrts (abnormal)
#    Frames: 1-292 (292 frames)
#    Source: w2fYQyikrts.mp4
#    ✅ Success! Saved to: cllba3xz8000p3o6lpaedkp88.mp4
#
# [1321/1383] Extracting: cllba4baj000t3o6lxfq01aok
#    Video: w2fYQyikrts (abnormal)
#    Frames: 351-615 (265 frames)
#    Source: w2fYQyikrts.mp4
#    ✅ Success! Saved to: cllba4baj000t3o6lxfq01aok.mp4
#
# [1322/1383] Extracting: cllba535b000x3o6l204nr8e8
#    Video: w2fYQyikrts (abnormal)
#    Frames: 627-920 (294 frames)
#    Source: w2fYQyikrts.mp4
#    ✅ Success! Saved to: cllba535b000x3o6l204nr8e8.mp4
#
# [1323/1383] Extracting: cllba5q1o00113o6lst176ho2
#    Video: w2fYQyikrts (abnormal)
#    Frames: 1008-1340 (333 frames)
#    Source: w2fYQyikrts.mp4
#    ✅ Success! Saved to: cllba5q1o00113o6lst176ho2.mp4
#
# [1324/1383] Extracting: cllba6aci00153o6lcl94c1sg
#    Video: w2fYQyikrts (abnormal)
#    Frames: 1353-1510 (158 frames)
#    Source: w2fYQyikrts.mp4
#    ✅ Success! Saved to: cllba6aci00153o6lcl94c1sg.mp4
# ❌ [1326/1383] cllba8jy4001a3o6lgjebwby8: Video file not found
# ❌ [1327/1383] cllbaa0xs001e3o6l6f5qxym8: Video file not found
# ❌ [1328/1383] cllbaaodb001i3o6lhi4odzpd: Video file not found
#
# [1328/1383] Extracting: cllbacor3001n3o6l6shinqqr
#    Video: Y547HGvC6rc (abnormal)
#    Frames: 248-722 (475 frames)
#    Source: Y547HGvC6rc.mp4
#    ✅ Success! Saved to: cllbacor3001n3o6l6shinqqr.mp4
#
# [1329/1383] Extracting: cllbkxxuf000c3o6l848vr3gz
#    Video: v1SoZ_S31pk (parkinsons)
#    Frames: 188-400 (213 frames)
#    Source: v1SoZ_S31pk.mp4
#    ✅ Success! Saved to: cllbkxxuf000c3o6l848vr3gz.mp4
#
# [1330/1383] Extracting: cllbxozns00053o6lttivp81c
#    Video: nXuJIs25z1U (normal)
#    Frames: 4952-5056 (105 frames)
#    Source: nXuJIs25z1U.mp4
#    ✅ Success! Saved to: cllbxozns00053o6lttivp81c.mp4
#
# [1331/1383] Extracting: cllbyadr3000a3o6ll9sc6eii
#    Video: EHymg4AGMJs (normal)
#    Frames: 4982-5071 (90 frames)
#    Source: EHymg4AGMJs.mp4
#    ✅ Success! Saved to: cllbyadr3000a3o6ll9sc6eii.mp4
#
# [1332/1383] Extracting: cllbyvxgt000u3o6l7nwi510j
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 12094-12120 (27 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllbyvxgt000u3o6l7nwi510j.mp4
#
# [1333/1383] Extracting: cllbywkb000103o6lmam65od6
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 12122-12161 (40 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllbywkb000103o6lmam65od6.mp4
#
# [1334/1383] Extracting: cllbyxjmr00163o6l8skxmujb
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 12163-12234 (72 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllbyxjmr00163o6l8skxmujb.mp4
#
# [1335/1383] Extracting: cllbyyh2a001c3o6lanqqhs7g
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 12235-12302 (68 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllbyyh2a001c3o6lanqqhs7g.mp4
#
# [1336/1383] Extracting: cllbyzkkm001i3o6l45u1jeg3
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 12365-12390 (26 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllbyzkkm001i3o6l45u1jeg3.mp4
#
# [1337/1383] Extracting: cllbz0tcd001o3o6l9xk6p1rd
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 12484-12580 (97 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllbz0tcd001o3o6l9xk6p1rd.mp4
#
# [1338/1383] Extracting: cllbz3nkx001u3o6lc1n8stel
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 12660-12725 (66 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllbz3nkx001u3o6lc1n8stel.mp4
#
# [1339/1383] Extracting: cllbz4yas00203o6lb5lv3xmr
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 13008-13090 (83 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllbz4yas00203o6lb5lv3xmr.mp4
#
# [1340/1383] Extracting: cllc0la2000263o6ldir88qnb
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 13195-13345 (151 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc0la2000263o6ldir88qnb.mp4
#
# [1341/1383] Extracting: cllc0njf1002c3o6lc9oewi8q
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 13910-14038 (129 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc0njf1002c3o6lc9oewi8q.mp4
#
# [1342/1383] Extracting: cllc0owv5002i3o6lf8nc9wez
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 14043-14095 (53 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc0owv5002i3o6lf8nc9wez.mp4
#
# [1343/1383] Extracting: cllc0qhax002m3o6ltjkzvput
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 14097-14171 (75 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc0qhax002m3o6ltjkzvput.mp4
#
# [1344/1383] Extracting: cllc0reid002s3o6l3w7ki23w
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 14239-14363 (125 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc0reid002s3o6l3w7ki23w.mp4
#
# [1345/1383] Extracting: cllc0t1oc002y3o6lz7j1wq4l
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 15354-15458 (105 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc0t1oc002y3o6lz7j1wq4l.mp4
#
# [1346/1383] Extracting: cllc0v8c100363o6l0tnitjgo
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 15619-15720 (102 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc0v8c100363o6l0tnitjgo.mp4
#
# [1347/1383] Extracting: cllc0wbia003c3o6lkgntlxxj
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 15870-15997 (128 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc0wbia003c3o6lkgntlxxj.mp4
#
# [1348/1383] Extracting: cllc0y22y003i3o6liek1w8k8
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 16093-16164 (72 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc0y22y003i3o6liek1w8k8.mp4
#
# [1349/1383] Extracting: cllc0zccl003o3o6lsxg9bxha
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 16639-16697 (59 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc0zccl003o3o6lsxg9bxha.mp4
#
# [1350/1383] Extracting: cllc10m7m003u3o6lzizfrn1k
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 16819-16846 (28 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc10m7m003u3o6lzizfrn1k.mp4
#
# [1351/1383] Extracting: cllc11h4u003y3o6lujf8deva
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 16961-17095 (135 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc11h4u003y3o6lujf8deva.mp4
#
# [1352/1383] Extracting: cllc136vu00423o6lz1gyo2p8
#    Video: hSIYGZhRGd4 (normal)
#    Frames: 17132-17220 (89 frames)
#    Source: hSIYGZhRGd4.mp4
#    ✅ Success! Saved to: cllc136vu00423o6lz1gyo2p8.mp4
#
# [1353/1383] Extracting: cllc1utlu001r3o6leofk2m9w
#    Video: MN4vnaNwIsA (normal)
#    Frames: 12400-12564 (165 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc1utlu001r3o6leofk2m9w.mp4
#
# [1354/1383] Extracting: cllc1x7j3001y3o6l3jo829my
#    Video: MN4vnaNwIsA (normal)
#    Frames: 12944-13105 (162 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc1x7j3001y3o6l3jo829my.mp4
#
# [1355/1383] Extracting: cllc1ylva00253o6le0hrppme
#    Video: MN4vnaNwIsA (normal)
#    Frames: 13172-13334 (163 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc1ylva00253o6le0hrppme.mp4
#
# [1356/1383] Extracting: cllc208i9002c3o6ls21a9v6i
#    Video: MN4vnaNwIsA (normal)
#    Frames: 13388-13540 (153 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc208i9002c3o6ls21a9v6i.mp4
#
# [1357/1383] Extracting: cllc21h2d002g3o6lq9rx96l1
#    Video: MN4vnaNwIsA (normal)
#    Frames: 13619-13774 (156 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc21h2d002g3o6lq9rx96l1.mp4
#
# [1358/1383] Extracting: cllc248am002q3o6lx58pvcyp
#    Video: MN4vnaNwIsA (normal)
#    Frames: 13841-13997 (157 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc248am002q3o6lx58pvcyp.mp4
#
# [1359/1383] Extracting: cllc26p7b002x3o6lmz7e7jh5
#    Video: MN4vnaNwIsA (normal)
#    Frames: 14068-14228 (161 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc26p7b002x3o6lmz7e7jh5.mp4
#
# [1360/1383] Extracting: cllc295kl00343o6ldnlgsc1i
#    Video: MN4vnaNwIsA (normal)
#    Frames: 14291-14448 (158 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc295kl00343o6ldnlgsc1i.mp4
#
# [1361/1383] Extracting: cllc2b2ja003b3o6lprua1g0l
#    Video: MN4vnaNwIsA (normal)
#    Frames: 14791-14943 (153 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc2b2ja003b3o6lprua1g0l.mp4
#
# [1362/1383] Extracting: cllc2gg5z003i3o6l7f4xc4qr
#    Video: MN4vnaNwIsA (normal)
#    Frames: 14982-15132 (151 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc2gg5z003i3o6l7f4xc4qr.mp4
#
# [1363/1383] Extracting: cllc2ioa7003q3o6lns793jmg
#    Video: MN4vnaNwIsA (normal)
#    Frames: 15177-15330 (154 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc2ioa7003q3o6lns793jmg.mp4
#
# [1364/1383] Extracting: cllc2jyqh003u3o6lmte5fdzt
#    Video: MN4vnaNwIsA (normal)
#    Frames: 15379-15519 (141 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc2jyqh003u3o6lmte5fdzt.mp4
#
# [1365/1383] Extracting: cllc2ljyk00413o6l0hx0vps0
#    Video: MN4vnaNwIsA (normal)
#    Frames: 15572-15731 (160 frames)
#    Source: MN4vnaNwIsA.mp4
#    ✅ Success! Saved to: cllc2ljyk00413o6l0hx0vps0.mp4
#
# [1366/1383] Extracting: clld3fen1003v3o6l9ecbpfk9
#    Video: vawElqwgo_k (abnormal)
#    Frames: 2852-3028 (177 frames)
#    Source: vawElqwgo_k.mp4
#    ✅ Success! Saved to: clld3fen1003v3o6l9ecbpfk9.mp4
#
# [1367/1383] Extracting: cllen39z8000v3o6l4x2kgvwe
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 6223-6741 (519 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllen39z8000v3o6l4x2kgvwe.mp4
#
# [1368/1383] Extracting: cllen5o7r00113o6lgnt7bym8
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 6742-7080 (339 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllen5o7r00113o6lgnt7bym8.mp4
#
# [1369/1383] Extracting: cllenanis001h3o6lsiozrhdi
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 8992-9145 (154 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenanis001h3o6lsiozrhdi.mp4
#
# [1370/1383] Extracting: cllencclk001n3o6lakdxfzps
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 9233-9399 (167 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllencclk001n3o6lakdxfzps.mp4
#
# [1371/1383] Extracting: cllendz0h001t3o6lkl4rhklc
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 9400-9489 (90 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllendz0h001t3o6lkl4rhklc.mp4
#
# [1372/1383] Extracting: clleng5wh001z3o6lpemlh9dy
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 9731-9819 (89 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: clleng5wh001z3o6lpemlh9dy.mp4
#
# [1373/1383] Extracting: cllenh9d100253o6lu2fyb0jk
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 9820-10140 (321 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenh9d100253o6lu2fyb0jk.mp4
#
# [1374/1383] Extracting: cllenjarj002b3o6ldef7ptm7
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 10732-11040 (309 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenjarj002b3o6ldef7ptm7.mp4
#
# [1375/1383] Extracting: cllenlhp2002h3o6luagefsxk
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 11041-11081 (41 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenlhp2002h3o6luagefsxk.mp4
#
# [1376/1383] Extracting: cllenmtfi002n3o6l56xcf72f
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 11082-11411 (330 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenmtfi002n3o6l56xcf72f.mp4
#
# [1377/1383] Extracting: cllenppvx002t3o6lxhjlee0a
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 11531-11638 (108 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenppvx002t3o6lxhjlee0a.mp4
#
# [1378/1383] Extracting: cllenrt11002z3o6lcmujqn8n
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 11655-11981 (327 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenrt11002z3o6lcmujqn8n.mp4
#
# [1379/1383] Extracting: cllenu3ga00333o6luwrwtc56
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 13314-13396 (83 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenu3ga00333o6luwrwtc56.mp4
#
# [1380/1383] Extracting: cllenvewz00393o6lvc1dc7qr
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 13397-13504 (108 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenvewz00393o6lvc1dc7qr.mp4
#
# [1381/1383] Extracting: cllenw3r8003g3o6ludxcf6jg
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 13505-13642 (138 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenw3r8003g3o6ludxcf6jg.mp4
#
# [1382/1383] Extracting: cllenx426003m3o6ld6v9zx31
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 13747-13964 (218 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenx426003m3o6ld6v9zx31.mp4
#
# [1383/1383] Extracting: cllenznbt003s3o6liisv7agr
#    Video: KnvYRnTA3XQ (normal)
#    Frames: 17762-17970 (209 frames)
#    Source: KnvYRnTA3XQ.mp4
#    ✅ Success! Saved to: cllenznbt003s3o6liisv7agr.mp4
#
# 🎉 SEQUENCE EXTRACTION COMPLETE!
# ✅ Successfully processed: 1310 sequences
# ❌ Failed extractions: 73 sequences
#
# 📋 Failed sequences:
#   • cljapdtb500593n6leoif0c32: Video file not found for jzkn287X-84
#   • cljapf2uw005d3n6lyasg3pn2: Video file not found for jzkn287X-84
#   • cljapfx0p005h3n6lkhemkjqe: Video file not found for jzkn287X-84
#   • cljapgo97005l3n6lbcz5g88s: Video file not found for jzkn287X-84
#   • cljaphipu005p3n6lde8gqkl7: Video file not found for jzkn287X-84
#   • cljapigcs005t3n6lrszkuyo2: Video file not found for jzkn287X-84
#   • cljapjdrt005x3n6lpw9b8d9p: Video file not found for jzkn287X-84
#   • cljapkbp500613n6lnp0i73x0: Video file not found for jzkn287X-84
#   • cljapl0g800653n6lqbg2u3dy: Video file not found for jzkn287X-84
#   • cljaplu8s00693n6ln0wqsmw9: Video file not found for jzkn287X-84
#   ... and 63 more failures
#
# 📁 All sequence videos are saved in: GAVD-sequences/
# 🔍 Each sequence is saved as: <sequence_id>.mp4
# 💡 Sequences are extracted based on frame numbers from the annotation data
